# %% [markdown]
# # Exploração de Dados - IGDB

# %% [markdown]
# ### Configurações Iniciais

# %%
# !spark-submit --version
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/usr/local/spark-3.2.1-bin-hadoop3.2/jars/spark-unsafe_2.12-3.2.1.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Welcome to
#       ____              __
#      / __/__  ___ _____/ /__
#     _\ \/ _ \/ _ `/ __/  '_/
#    /___/ .__/\_,_/_/ /_/\_\   version 3.2.1
#       /_/
#
# Using Scala version 2.12.15, OpenJDK 64-Bit Server VM, 11.0.15
# Branch HEAD
# Compiled by user hgao on 2022-01-20T19:26:14Z
# Revision 4f25b3f71238a00508a356591553f2dfa89f8290
# Url https://github.com/apache/spark
# Type --help for more information.

# %%
from pyspark.sql.types import *
import pyspark.sql.functions as fn
from pyspark.sql import SparkSession
from IPython.core.display import HTML

display(HTML("<style>pre { white-space: pre !important; }</style>"))

# Define a sessão do Spark com os jars necessários para conexão com o MINIO
spark = (SparkSession.builder
         .config("spark.jars","""/home/jovyan/jars/aws-java-sdk-core-1.11.534.jar,
                                 /home/jovyan/jars/aws-java-sdk-dynamodb-1.11.534.jar,
                                 /home/jovyan/jars/aws-java-sdk-s3-1.11.534.jar,
                                 /home/jovyan/jars/hadoop-aws-3.2.2.jar""")
         .config("spark.jars.packages", "io.delta:delta-core_2.12:2.0.0")
         .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
         .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
         .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000")
         .config("spark.hadoop.fs.s3a.access.key", "aulafia")
         .config("spark.hadoop.fs.s3a.secret.key", "aulafia@123")
         .config("spark.hadoop.fs.s3a.path.style.access", True)
         .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
         .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider")
         .getOrCreate()
        )

from delta.tables import DeltaTable
# Out:
# <style>pre { white-space: pre !important; }</style>

# %%
# Nome do bucket
bucket_name = "raw"

# Define o nome da API de onde foram extraídos os dados via arquivo JSON
api_name = 'igdb'

# Define o path do bucket dos dados
bucket_path = 's3a://' + bucket_name + '/' + api_name + '/'

# %% [markdown]
# ## Games

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'games'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Games = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Games.show(20, False)
# Out:
# +---------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------+--------------------------------------------------------------+-----------------------------+--------+------------------------------------+----------+------+----------+----+--------------+----------+---------------------------------------------------------------------------------------+------------------+-------+-----+---------+----------+------------+------------------+----------+--------------------+-----+---+-------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------+------------------------------------------------+-----------+-------------------------+-------------------+--------+-----------------+------------+-----------------------------------------------------------------------------+--------+---------+------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------------------------------------------+---------------------+------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |age_ratings                            |aggregated_rating|aggregated_rating_count|alternative_names                                                   |artworks                                                      |bundles                      |category|checksum                            |collection|cover |created_at|dlcs|expanded_games|expansions|external_games                                                                         |first_release_date|follows|forks|franchise|franchises|game_engines|game_localizations|game_modes|genres              |hypes|id |involved_companies             |keywords                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |language_supports                                                                                                                                                                       |multiplayer_modes|name                                            |parent_game|platforms                |player_perspectives|ports   |rating           |rating_count|release_dates                                                                |remakes |remasters|screenshots                                                                                     |similar_games                                                             |slug                                           |standalone_expansions|status|storyline                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# +---------------------------------------+-----------------+-----------------------+--------------------------------------------------------------------+--------------------------------------------------------------+-----------------------------+--------+------------------------------------+----------+------+----------+----+--------------+----------+---------------------------------------------------------------------------------------+------------------+-------+-----+---------+----------+------------+------------------+----------+--------------------+-----+---+-------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------
null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |null                                                                                                                                                                                    |null             |Baldur's Gate                                   |null       |[3, 6, 14, 39]           |[3]                |null    |86.00253703266303|288         |[28327, 124722, 149982, 178907]                                              |null    |[1880]   |[15541, 136331, 136332, 136333]                                                                 |[19127, 19404, 22790, 49414, 54775, 57033, 69007, 99118, 113636, 113910]  |baldur-s-gate                                  |null                 |null  |Candlekeep is an ancient fortress situated on the rural Sword Coast. Recently, inexplicable events have been plaguing this quiet place, which has long become a large library where men of wisdom and knowledge can study in peace. Unknown mercenaries try to enter the walls of Candlekeep, interested in a seemingly ordinary and unimportant young person - an orphan who was taken in by the mage Gorion and treated by him as his own child. One night, Gorion decides to leave Candlekeep and take his adopted child to a safe place. However, as they leave the fortress, they are ambushed by a group of assassins. The orphan manages to escape, but Gorion dies in battle.\n\nThe gates of Candlekeep are locked, because its inhabitants are afraid to attract to themselves the wrath of the mysterious attackers. Only Imoen, another child who was brought up by Gorion and has been like a sister to the protagonist, is willing to share the uncertain future. The two have nothing, no place to call their home, only a wide hostile world in front of them. A long and perilous journey begins there.\n\nBaldur's Gate is a role-playing game that uses the rule set of Advanced Dungeons & Dragons (AD&D). Set in the universe of Forgotten Realms, the game is the first part of the saga that lets the player explore various towns, wilderness areas and dungeons, undertake many side quests, and find companions for the long journey. The player creates the hero(ine) by selecting his or her class, choosing between fighter, thief, mage, priest, ranger, and druid (including sub-classes, dual- and multi-class characters); alignment (Good-Evil and Lawful-Chaotic axis), and weapon proficiencies. The 2nd edition AD&D rules are applied in the game during combat, character leveling, class restrictions, etc.\n\nUp to six player-controlled characters can participate in combat. Battles occur in the same environment as exploration, and flow in real time, thou ...
# |[28016, 72539]                         |90.0             |1                      |[28476, 56448, 68627, 68628, 135189]                                |null                                                          |[141859]                     |0       |5d436362-6c2d-aaa5-2f50-feca4d99205a|7         |329139|1297562986|null|null          |[82]      |[37730, 73001, 147323, 250663]                                                         |969494400         |156    |null |null     |[43]      |[28]        |null              |[1, 3]    |[12]                |null |6  |[14, 158, 18474, 18475]        |[211, 226, 415, 497, 558, 592, 989, 1162, 1345, 1396, 1523, 1779, 2066, 2170, 2452, 2472, 3222, 4132, 4134, 4249, 4272, 4285, 4287, 4346, 4359, 4388, 4392, 4399, 4406, 4468, 4613, 4693, 4702, 4759, 4780, 4823, 4850, 4852, 4855, 4862, 4879, 4891, 4998, 5029, 5181, 5389, 5476, 5517, 5591, 5659, 5673, 5988, 6057, 6061, 6062, 6069, 6074, 6324, 6486, 6620, 6642, 6656, 6681, 6702, 6716, 6733, 7161, 7423, 7437, 7440, 7463, 7698, 9339, 9567, 9661, 9667, 15373]                                                                                                                                                                                                                                                                                                                              |null                                                                                                                                                                                    |[1920]           |Baldur's Gate II: Shadows of Amn                |null       |[3, 6, 14]               |[3]                |null    |88.17222196525518|411         |[28326, 124724, 124725, 124726]                                              |null    |[5613]   |[9163, 11341, 11342, 11343, 11344]                                                              |[59, 214, 216, 255, 472, 753, 832, 1593, 2365, 8747]                      |baldurs-gate-ii-shadows-of-amn                 |null                 |null  |Some time after the events described in Baldur's Gate, the protagonist and his friends Imoen, Minsc and Jaheira have been captured by an elven mage called Jon Irenicus. His intentions and connection to the heroes unknown, Irenicus conducts experiments on them, holding them in cages somewhere in his vast underground complex. During his absence, the heroes manage to escape, and soon find themselves in the city of Athkatla in the country of Amn, where they confront Irenicus. However, at that moment several wizards arrive and arrest both Irenicus and Imoen for unlicensed use of magic. The first task at hand is to raise the money needed to rescue Imoen, before facing Irenicus again and unraveling his true goals.\n\nBaldur's Gate II: Shadows of Amn is a party-based role-playing game using the AD&D rules. The basic gameplay is similar to that of its predecessor: the player navigates a party of up to six active combatants over isometric environments, conversing with non-playable characters using branching dialogue, and fighting enemies in real-time, free-movement combat that can be paused to issue specific orders to the characters. World traveling now occurs by selecting locations on a map rather than exploring wilderness areas to reach the destination. However, the game world is larger than in the previous game, with more individual locations to visit and side quests to perform.\n\nBeing a direct sequel to Baldur's Gate, the game lets the player control stronger, higher-level characters from the onset. The main character can also be imported from the previous installment. Three new classes (sorcerer, monk, and barbarian) are available along with those that were present in the original game. Characters can also acquire specializations within most of the classes: a paladin, for instance, can become a dragon slayer or an inquisitor. Weapon proficiencies are more specific: for example, instead of just specia ...
# |[81513, 123839]                        |null             |null                   |null                                                                |null                                                          |null                         |0       |7d307d18-1a13-1b35-5eaa-886afaeb6903|73        |8     |1297563812|null|null          |null      |[29868, 77379, 134883, 147413, 218226, 248022]                                         |770515200         |5      |null |null     |null      |null        |null              |[1]       |[12, 15, 16, 24]    |null |7  |[4302, 4303]                   |[1, 415, 2452, 4248, 4259, 5323, 6623]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |[478849, 478850]                                                                                                                                                                        |null             |Jagged Alliance                                 |null       |[13, 20]                 |[3]                |[53254] |79.12208576903184|19          |[4329]                                                                       |null    |null     |[162109, 162110, 162111, 162112, 162113, 162114, 162115, 162116, 162117, 162118]                |[7615, 8422, 13196, 14394, 26268, 26845, 36258, 58075, 102057, 119171]    |jagged-alliance                                |null                 |null  |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# |[68417, 123885]                        |null             |null                   |null                                                                |null                                                          |[29194, 53252]               |0       |0fdf1f9e-8bcf-9a99-1105-7098752ffea1|73        |104633|1297563845|null|null          |null      |[15132, 77380, 85965, 156188, 247671]                                                  |932688000         |22     |null |null     |null      |null        |null              |[1]       |[12, 15, 16, 24, 31]|null |9  |[681, 682, 683]                |[1, 147, 151, 226, 359, 415, 563, 578, 604, 1158, 1320, 1821, 2242, 2452, 3831, 4134, 4179, 4248, 4259, 4273, 4397, 4404, 5323, 5789, 5814, 6048, 6295, 6623, 6642, 6656, 6716, 7440, 8691, 9890, 14506]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |[437081, 478040]                                                                                                                                                                        |null             |Jagged Alliance 2                               |null       |[3, 6, 16]               |[3]                |null    |86.91040144835398|39          |[515, 516, 517]                                                              |[1008]  |null     |[990, 991, 992, 993, 994]                                                                       |[2365, 5652, 9278, 9363, 9938, 10388, 14394, 22387, 26845, 119171]        |jagged-alliance-2                              |[10466, 51205]       |null  |A ruthless dictator has taken control of the tiny nation of Arulco. The country's brutal army is holding the terrified population in its iron grip. The only opposition is a ragtag bunch of rebels. The bad news: you're in charge of the rebels. The good news: some of the world's best mercenaries will fight on your side... that is if you can afford them.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
#
array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- bundles: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- category: long (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- collection: long (nullable = true)
#  |-- cover: long (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- dlcs: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- expanded_games: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- expansions: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- external_games: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- first_release_date: timestamp (nullable = true)
#  |-- follows: long (nullable = true)
#  |-- forks: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- franchise: long (nullable = true)
#  |-- franchises: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- game_engines: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- game_localizations: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- game_modes: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- genres: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- hypes: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- involved_companies: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- keywords: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- language_supports: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- multiplayer_modes: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- name: string (nullable = true)
#  |-- parent_game: long (nullable = true)
#  |-- platforms: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- player_perspectives: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- ports: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- rating: double (nullable = true)
#  |-- rating_count: long (nullable = true)
#  |-- release_dates: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- remakes: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- remasters: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- screenshots: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- similar_games: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- slug: string (nullable = true)
#  |-- standalone_expansions: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- status: long (nullable = true)
#  |-- storyline: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- tags: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- themes: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- total_rating: double (nullable = true)
#  |-- total_rating_count: long (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- url: string (nullable = true)
#  |-- version_parent: long (nullable = true)
#  |-- version_title: string (nullable = true)
#  |-- videos: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- websites: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %% [markdown]
# #### Todos os registros do Dataframe são únicos, considerando a chave ID

# %%
dfIGDB_Games.count()
# Out:
# 256043

# %%
dfIGDB_Games.select("id").distinct().count()
# Out:
# 249891

# %% [markdown]
# #### Describe dos campos numéricos

# %%
dfIGDB_Games.describe().show()
# Out:
# +-------+-----------------+-----------------------+------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+--------+-----------------+------------------+------------------+--------+------------------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+------------------+
# |summary|aggregated_rating|aggregated_rating_count|          category|            checksum|        collection|             cover|           follows|         franchise|             hypes|                id|    name|      parent_game|            rating|      rating_count|    slug|            status|           storyline|             summary|      total_rating|total_rating_count|                 url|   version_parent|     version_title|
# +-------+-----------------+-----------------------+------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+--------+-----------------+------------------+------------------+--------+------------------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+------------------+
# |  count|            14914|                  14914|            243114|              243114|             36445|            179781|             23234|              1516|              9550|            243114|  243114|            28123|             29193|             29193|  243114|             15353|               20817|              205277|             34393|             34393|              243114|             5911|              5838|
# |   mean|69.02261076363563|       3.62840284296634|0.6738361427149403|                null| 3254.880834133626|180668.25360855708|10.722733924421107|132.43139841688654| 3.734764397905759|130430.70959714372|Infinity|64061.63204494542| 66.67204818652547|22.555578392080292|Infinity| 4.288608089624177|                null|              2017.0| 66.51113979734431| 20.71872183293112|                null|80372.13381830485|               1.6|
# | stddev|16.16925141150059|      4.074382243100509| 2.363966773874665|                null|2582.9115447396384| 91255.30022075653| 45.86757143008876|122.19873405337616|17.818799025873272| 75313.52388692318|     NaN|68487.09204819326|14.323879475981686| 109.1219257803485|     NaN|1.5326517760326477|                null|                 0.0|14.706957394214818|102.21910815594842|                null| 72006.0883733238|0.6928203230275509|
# |    min|              0.0|                      0|                 0|00002f95-fcec-913...|                 1|                 8|                 1|                 1|                 1|                 1|       !|                1| 10.00196599837262|                 0|      --|                 0|" Visions—\n\nThe...|\r\nSo this is a ...|               0.0|                 0|https://www.igdb....|                4|        "Censored"|
# |    max|            100.0|                     59|                14|ffff7adb-3dcc-e49...|              8923|            323653|              1798|               444|              1038|            261446|Ａ Class|           261280|             100.0|              3943|   zzzzz|                 8|﻿As the wizarding...|🌿 Sacramento is ...|             100.0|              3980|https://www.igdb....|           260879|       세번의 키스|
# +-------+-----------------+-----------------------+------------------+--------------------+------------------+------------------+------------------+------------------+------------------+------------------+--------+-----------------+------------------+------------------+--------+------------------+--------------------+--------------------+------------------+------------------+--------------------+-----------------+------------------+

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_Games = (dfIGDB_Games
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("first_release_date", fn.to_timestamp(fn.from_unixtime("first_release_date")))
           dfIGDB_Games.describe().show()     .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %%
import pandas as pd

pandas_df = dfIGDB_Games.toPandas()

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 8.0 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pandas_df = pandas_df.drop('summary', axis=1)

# %%
pandas_df = pandas_df.drop('storyline', axis=1)

# %%
pandas_df.count()
# Out:
# age_ratings                 56161
# aggregated_rating           14942
# aggregated_rating_count     14942
# alternative_names           56117
# artworks                    92643
# bundles                     10890
# category                   244906
# checksum                   244906
# collection                  36584
# cover                      181298
# created_at                 244906
# dlcs                         2536
# expanded_games               1119
# expansions                    665
# external_games             231278
# first_release_date         154862
# follows                     23321
# forks                          48
# franchise                    1516
# franchises                  18681
# game_engines                21096
# game_localizations          22475
# game_modes                 129052
# genres                     196762
# hypes                        9550
# id                         244906
# involved_companies         104535
# keywords                    81466
# language_supports          111127
# multiplayer_modes           10649
# name                       244906
# parent_game                 28716
# platforms                  163441
# player_perspectives         79496
# ports                        3217
# rating                      29225
# rating_count                29225
# release_dates              162403
# remakes                       787
# remasters                     802
# screenshots                173793
# similar_games              201543
# slug                       244906
# standalone_expansions         250
# status                      15449
# tags                       201561
# themes                     130485
# total_rating                34438
# total_rating_count          34438
# updated_at                 244906
# url                        244906
# version_parent               5954
# version_title                5881
# videos                      53170
# websites                   227575
# dtype: int64

# %%
pandas_df.to_csv("/home/jovyan/notebooks/dfIGDB_Games.csv", index=False)

# %% [markdown]
# #### Exploração

# %%
# Games atualizados recentemente (considerando a última ingestão até a data da análise)
(dfIGDB_Games
 .select("name", "updated_at")
 .orderBy(fn.col("updated_at").desc())
).show(10, False)
# Out:
# +---------------------------+----------+
# |name                       |updated_at|
# +---------------------------+----------+
# |TheHunter: Call of the Wild|1692054284|
# |Paper Planet               |1692053424|
# |For Honor                  |1692053377|
# |Ghosts of Tabor            |1692053339|
# |Battlefield 2042           |1692053337|
# |Colossal Cave              |1692053314|
# |The Darkside Detective     |1692050900|
# |Roguelight                 |1692050898|
# |Neon Tail                  |1692050891|
# |Dungeon Nightmares         |1692050884|
# +---------------------------+----------+
# only showing top 10 rows

# %%
# Games mais bem avaliados
(dfIGDB_Games
 .select("id", "name", "rating")
 .orderBy(fn.col("rating").desc())
).show(10, False)
# Out:
# +------+----------------------------------------+-----------------+
# |id    |name                                    |rating           |
# +------+----------------------------------------+-----------------+
# |8863  |Age of Wonders III: Golden Realms       |100.0            |
# |88973 |Goblin Sword                            |99.94224659928568|
# |20196 |Metal Gear Solid: The Legacy Collection |99.68039606212281|
# |41888 |Battlefield 3: Premium Edition          |99.67350381707095|
# |50261 |Angband                                 |99.63776240578409|
# |45131 |Grand Theft Auto V: Special Edition     |99.59974553815321|
# |204360|Goat Simulator 3                        |99.5558811519708 |
# |11226 |Anstoss 3                               |99.53177623237173|
# |122661|Gwent: Iron Judgment                    |99.38977451446661|
# |164664|Sekiro: Shadows Die Twice - GOTY Edition|99.36728476578347|
# +------+----------------------------------------+-----------------+
# only showing top 10 rows

# %% [markdown]
# ## Genres

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'genres'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Genres = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Genres.show(truncate=False)
# Out:
# +------------------------------------+----------+---+--------------------------+-------------------------+----------+-----------------------------------------------------+
# |checksum                            |created_at|id |name                      |slug                     |updated_at|url                                                  |
# +------------------------------------+----------+---+--------------------------+-------------------------+----------+-----------------------------------------------------+
# |ef2ff68a-f7bd-d2d0-76cb-c830bd6e3191|1297555200|2  |Point-and-click           |point-and-click          |1323302400|https://www.igdb.com/genres/point-and-click          |
# |2ccc6572-bdde-6ed4-8843-25447ea40782|1297555200|4  |Fighting                  |fighting                 |1323216000|https://www.igdb.com/genres/fighting                 |
# |bb15fd3f-0f46-e5f3-2b40-d046cf9bd2ef|1297555200|5  |Shooter                   |shooter                  |1323216000|https://www.igdb.com/genres/shooter                  |
# |22d44a0d-89c7-580f-eef2-e06f178fdd47|1297555200|7  |Music                     |music                    |1323216000|https://www.igdb.com/genres/music                    |
# |697fc5a4-b96f-a803-288a-498bd5dd1de1|1297555200|8  |Platform                  |platform                 |1323216000|https://www.igdb.com/genres/platform                 |
# |616de9c3-8a00-0232-9df9-00014cfac51b|1297555200|9  |Puzzle                    |puzzle                   |1323216000|https://www.igdb.com/genres/puzzle                   |
# |73c2653f-54d8-c1bd-d523-dd57fb753194|1297555200|10 |Racing                    |racing                   |1323216000|https://www.igdb.com/genres/racing                   |
# |aaa36cbc-2258-8653-a461-1358df8ce445|1297555200|11 |Real Time Strategy (RTS)  |real-time-strategy-rts   |1323216000|https://www.igdb.com/genres/real-time-strategy-rts   |
# |42dea3b2-7fe2-e734-91cd-f80ce62a14c3|1297555200|12 |Role-playing (RPG)        |role-playing-rpg         |1323216000|https://www.igdb.com/genres/role-playing-rpg         |
# |9779772a-f08f-9e8e-bd26-70c9eecc34e8|1297555200|13 |Simulator                 |simulator                |1323216000|https://www.igdb.com/genres/simulator                |
# |e598c458-3e21-7a14-50a5-ea53733ab22f|1297555200|14 |Sport                     |sport                    |1323216000|https://www.igdb.com/genres/sport                    |
# |d7863f95-0f2c-0f2d-c1e9-29d06eaf3396|1297555200|15 |Strategy                  |strategy                 |1323216000|https://www.igdb.com/genres/strategy                 |
# |af5d3ecd-2ebd-358b-70df-e9204b9761be|1297641600|16 |Turn-based strategy (TBS) |turn-based-strategy-tbs  |1323216000|https://www.igdb.com/genres/turn-based-strategy-tbs  |
# |6132b15f-289e-60ea-5957-7c78b97053a2|1300924800|24 |Tactical                  |tactical                 |1323216000|https://www.igdb.com/genres/tactical                 |
# |4bd95a5d-8fa1-1aee-4ea9-224b4b1312f7|1301616000|25 |Hack and slash/Beat 'em up|hack-and-slash-beat-em-up|1323216000|https://www.igdb.com/genres/hack-and-slash-beat-em-up|
# |256a99dd-dd06-bc0c-d53b-dc3098da4d49|1301961600|26 |Quiz/Trivia               |quiz-trivia              |1323216000|https://www.igdb.com/genres/quiz-trivia              |
# |b5657d72-ee36-0851-58df-e8d2413283f8|1320192000|30 |Pinball                   |pinball                  |1323216000|https://www.igdb.com/genres/pinball                  |
# |a6d85192-8d11-bad3-cc5c-dd89e2f94a47|1323561600|31 |Adventure                 |adventure                |1323561600|https://www.igdb.com/genres/adventure                |
# |2522259f-2454-ec02-5dc0-84373e0508ed|1341360000|32 |Indie                     |indie                    |1341360000|https://www.igdb.com/genres/indie                    |
# |388cec36-d099-f4a1-31c3-f938fae9067b|1380931200|33 |Arcade                    |arcade                   |1380931200|https://www.igdb.com/genres/arcade                   |
# +------------------------------------+----------+---+--------------------------+-------------------------+----------+-----------------------------------------------------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_Genres.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_Genres.count()
# Out:
# 23

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_Genres = (dfIGDB_Genres
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Exploração

# %%
# Número de Games por Gênero (considerando multi-classificação)
dfGamesByGenre = (dfIGDB_Games
 .select("id", fn.explode_outer("genres").alias("genre_id"))
 .groupBy("genre_id")
 .agg(fn.count("id").alias("games"))
 .orderBy("genre_id")
)

total_titles = dfGamesByGenre.agg(fn.sum("games")).collect()[0][0]

(dfGamesByGenre
 .join(dfIGDB_Genres, dfGamesByGenre.genre_id == dfIGDB_Genres.id, how="left")
 .withColumn("name", fn.when(fn.col("name").isNull(), "Undefined")
                             .otherwise(fn.col("name")))
 .withColumn("Percent", fn.round(((fn.col("Games") / total_titles) * 100), 2))
 .select(fn.col("name").alias("Genre"), fn.col("games").alias("Games"), "Percent")
 .orderBy(fn.col("Games").desc())
).show(truncate=False)
# Out:
# +--------------------------+-----+-------+
# |Genre                     |Games|Percent|
# +--------------------------+-----+-------+
# |Indie                     |77364|18.56  |
# |Adventure                 |63632|15.27  |
# |Undefined                 |48187|11.56  |
# |Simulator                 |35272|8.46   |
# |Strategy                  |32439|7.78   |
# |Role-playing (RPG)        |26778|6.42   |
# |Puzzle                    |21036|5.05   |
# |Shooter                   |17856|4.28   |
# |Arcade                    |17344|4.16   |
# |Platform                  |14865|3.57   |
# |Sport                     |14439|3.46   |
# |Racing                    |10149|2.44   |
# |Visual Novel              |7596 |1.82   |
# |Fighting                  |5160 |1.24   |
# |Turn-based strategy (TBS) |3753 |0.9    |
# |Point-and-click           |3710 |0.89   |
# |Hack and slash/Beat 'em up|3571 |0.86   |
# |Music                     |3048 |0.73   |
# |Card & Board Game         |2994 |0.72   |
# |Tactical                  |2653 |0.64   |
# +--------------------------+-----+-------+
# only showing top 20 rows

# %% [markdown]
# ## Game Modes

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'game_modes'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_GameModes = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_GameModes.show(truncate=False)
# Out:
# +------------------------------------+----------+---+----------------------------------+--------------------------------+----------+----------------------------------------------------------------+
# |checksum                            |created_at|id |name                              |slug                            |updated_at|url                                                             |
# +------------------------------------+----------+---+----------------------------------+--------------------------------+----------+----------------------------------------------------------------+
# |a43b1688-f968-3541-0897-9735ffde1745|1298937600|1  |Single player                     |single-player                   |1323216000|https://www.igdb.com/game_modes/single-player                   |
# |288b548c-11e4-d910-f037-21d4e6a33b38|1298937600|2  |Multiplayer                       |multiplayer                     |1323216000|https://www.igdb.com/game_modes/multiplayer                     |
# |e8329d55-33e6-f7ae-ae09-2848cb7ccc90|1298937600|3  |Co-operative                      |co-operative                    |1323216000|https://www.igdb.com/game_modes/co-operative                    |
# |98247b75-6f46-7c77-521f-0945c684d842|1298937600|4  |Split screen                      |split-screen                    |1323216000|https://www.igdb.com/game_modes/split-screen                    |
# |307d1126-6e3b-9215-06f1-10c8ecce05b4|1298937600|5  |Massively Multiplayer Online (MMO)|massively-multiplayer-online-mmo|1323216000|https://www.igdb.com/game_modes/massively-multiplayer-online-mmo|
# |bfc388ac-0502-ba05-af25-3dcc94a0acf3|1588809600|6  |Battle Royale                     |battle-royale                   |1588809600|https://www.igdb.com/game_modes/battle-royale                   |
# +------------------------------------+----------+---+----------------------------------+--------------------------------+----------+----------------------------------------------------------------+

# %%
# Exibe o Schema do DataFrame
dfIGDB_GameModes.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_GameModes.count()
# Out:
# 6

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_GameModes = (dfIGDB_GameModes
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Exploração

# %%
# Número de Games por Modo de Jogo (considerando multi-classificação)
dfGamesByGameMode = (dfIGDB_Games
 .select("id", fn.explode_outer("game_modes").alias("gmode_id"))
 .groupBy("gmode_id")
 .agg(fn.count("id").alias("games"))
 .orderBy("gmode_id")
)

total_titles = dfGamesByGameMode.agg(fn.sum("games")).collect()[0][0]

(dfGamesByGameMode
 .join(dfIGDB_GameModes, dfGamesByGameMode.gmode_id == dfIGDB_GameModes.id, how="left")
 .withColumn("name", fn.when(fn.col("name").isNull(), "Undefined")
                             .otherwise(fn.col("name")))
 .withColumn("Percent", fn.round(((fn.col("Games") / total_titles) * 100), 2))
 .select(fn.col("name").alias("Game Mode"), fn.col("games").alias("Games"), "Percent")
 .orderBy(fn.col("Games").desc())
).show(truncate=False)
# Out:
# +----------------------------------+------+-------+
# |Game Mode                         |Games |Percent|
# +----------------------------------+------+-------+
# |Single player                     |121367|42.54  |
# |Undefined                         |115136|40.36  |
# |Multiplayer                       |29065 |10.19  |
# |Co-operative                      |12109 |4.24   |
# |Massively Multiplayer Online (MMO)|3586  |1.26   |
# |Split screen                      |3500  |1.23   |
# |Battle Royale                     |523   |0.18   |
# +----------------------------------+------+-------+

# %% [markdown]
# ## Player Perspectives

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'player_perspectives'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_PlayerPersp = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_PlayerPersp.show(truncate=False)
# Out:
# +------------------------------------+-------------------+---+---------------------+-------------------------+-------------------+------------------------------------------------------------------+
# |checksum                            |created_at         |id |name                 |slug                     |updated_at         |url                                                               |
# +------------------------------------+-------------------+---+---------------------+-------------------------+-------------------+------------------------------------------------------------------+
# |4e23cb22-7a70-effb-b8e1-151317c6cdbd|2011-03-01 00:00:00|1  |First person         |first-person             |2011-12-07 00:00:00|https://www.igdb.com/player_perspectives/first-person             |
# |2788b856-580c-66d0-bef3-d6169034f175|2011-03-01 00:00:00|2  |Third person         |third-person             |2011-12-07 00:00:00|https://www.igdb.com/player_perspectives/third-person             |
# |83c59132-6edd-150f-a25f-a86ddf6a0da3|2011-03-01 00:00:00|3  |Bird view / Isometric|bird-view-slash-isometric|2020-02-24 00:00:00|https://www.igdb.com/player_perspectives/bird-view-slash-isometric|
# |2d038ac6-36c5-af5b-83fd-11a88a638631|2011-03-01 00:00:00|4  |Side view            |side-view                |2011-12-07 00:00:00|https://www.igdb.com/player_perspectives/side-view                |
# |e2df3906-bca8-e0d1-ca3b-67e1c5cfb334|2011-11-14 00:00:00|5  |Text                 |text                     |2011-12-07 00:00:00|https://www.igdb.com/player_perspectives/text                     |
# |74528cf1-64c3-cd78-18df-fae1594ee664|2014-10-13 00:00:00|6  |Auditory             |auditory                 |2020-02-24 00:00:00|https://www.igdb.com/player_perspectives/auditory                 |
# |963f8a54-d40f-1c9d-3bf4-d15267043693|2016-05-03 00:00:00|7  |Virtual Reality      |virtual-reality          |2016-05-03 00:00:00|https://www.igdb.com/player_perspectives/virtual-reality          |
# +------------------------------------+-------------------+---+---------------------+-------------------------+-------------------+------------------------------------------------------------------+

# %%
# Exibe o Schema do DataFrame
dfIGDB_PlayerPersp.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_PlayerPersp.count()
# Out:
# 7

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_PlayerPersp = (dfIGDB_PlayerPersp
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at", 'yyyy-MM-dd HH:mm:ss')))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at", 'yyyy-MM-dd HH:mm:ss')))
               )

# %% [markdown]
# #### Exploração

# %%
# Número de Games por Perspectiva de Jogador (considerando multi-classificação)
dfGamesByPersp = (dfIGDB_Games
 .select("id", fn.explode_outer("player_perspectives").alias("persp_id"))
 .groupBy("persp_id")
 .agg(fn.count("id").alias("games"))
 .orderBy("persp_id")
)

total_titles = dfGamesByPersp.agg(fn.sum("games")).collect()[0][0]

(dfGamesByPersp
 .join(dfIGDB_PlayerPersp, dfGamesByPersp.persp_id == dfIGDB_PlayerPersp.id, how="left")
 .withColumn("name", fn.when(fn.col("name").isNull(), "Undefined")
                             .otherwise(fn.col("name")))
 .withColumn("Percent", fn.round(((fn.col("Games") / total_titles) * 100), 2))
 .select(fn.col("name").alias("Player Perspective"), fn.col("games").alias("Games"), "Percent")
 .orderBy(fn.col("Games").desc())
).show(truncate=False)
# Out:
# +---------------------+------+-------+
# |Player Perspective   |Games |Percent|
# +---------------------+------+-------+
# |Undefined            |164837|64.69  |
# |Bird view / Isometric|22132 |8.69   |
# |Side view            |20627 |8.1    |
# |Third person         |20148 |7.91   |
# |First person         |17486 |6.86   |
# |Text                 |6660  |2.61   |
# |Virtual Reality      |2293  |0.9    |
# |Auditory             |611   |0.24   |
# +---------------------+------+-------+

# %% [markdown]
# ## Platforms

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'platforms'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Platforms = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Platforms.show(20, truncate=False)
# Out:
# +------------+--------------------+--------+------------------------------------+----------+----------+---+-----------------------------------+---------------+-------------+-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+--------------------------------------+-----------------------------------------------------------+--------+
# |abbreviation|alternative_name    |category|checksum                            |created_at|generation|id |name                               |platform_family|platform_logo|slug   |summary                                                                                                                                                                                                                                                                                                                                                 |updated_at|url                                   |versions                                                   |websites|
# +------------+--------------------+--------+------------------------------------+----------+----------+---+-----------------------------------+---------------+-------------+-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+--------------------------------------+-----------------------------------------------------------+--------+
# |Linux       |GNU/Linux           |4       |b810fb9c-65f7-b297-3658-da9c4d52bf11|1297555200|null      |3  |Linux                              |4              |380          |linux  |Linux is a free and open-source (FOSS/FLOSS) Operating System. In a more precise and complex definition, Linux is an open-source OS kernel on which a large variety of Operating Systems (known as Linux distributions) are built.                                                                                                                      |1392940800|https://www.igdb.com/platforms/linux  |[44]                                                       |[1]     |
# |N64         |N64                 |1       |647c6004-3c75-3b8d-8259-79bd3d5e5a28|1297555200|5         |4  |Nintendo 64                        |5              |260          |n64    |null                                                                                                                                                                                                                                                                                                                                                    |1565136000|https://www.igdb.com/platforms/n64    |[51, 122]                                                  |[35]    |
# |Wii         |Revolution          |1       |d56c975f-909c-1af3-bdf6-e57c03e11bce|1297639288|7         |5  |Wii                                |5              |326          |wii    |null                                                                                                                                                                                                                                                                                                                                                    |1615884750|https://www.igdb.com/platforms/wii    |[72, 283]                                                  |[275]   |
# |PC          |mswin               |4       |5aae54d0-390e-a4ec-a9ee-4ad4cc346992|1297555200|null      |6  |PC (Microsoft Windows)             |null           |203          |win    |null                                                                                                                                                                                                                                                                                                                                                    |1470009600|https://www.igdb.com/platforms/win    |[1, 13, 14, 15, 124]                                       |[2]     |
# |PS1         |PSX, PSOne, PS      |1       |b6644b7a-e4ba-7cd8-4a42-3176f9a1c053|1297639288|5         |7  |PlayStation                        |1              |278          |ps     |null                                                                                                                                                                                                                                                                                                                                                    |1633117147|https://www.igdb.com/platforms/ps     |[57]                                                       |null    |
# |PS2         |PS2                 |1       |be3e025c-d4ed-b795-443c-a8cb55fbfe17|1297555200|6         |8  |PlayStation 2                      |1              |254          |ps2    |null                                                                                                                                                                                                                                                                                                                                                    |1414972800|https://www.igdb.com/platforms/ps2    |[58, 114]                                                  |null    |
# |PS3         |PS3                 |1       |f6375299-72fe-d71c-6471-665a2de34930|1297639288|7         |9  |PlayStation 3                      |1              |79           |ps3    |null                                                                                                                                                                                                                                                                                                                                                    |1633117060|https://www.igdb.com/platforms/ps3    |[4, 5, 6]                                                  |[3]     |
# |XBOX        |null                |1       |226780a3-83ed-dcf9-6757-77091acc172d|1297555200|6         |11 |Xbox                               |2              |266          |xbox   |null                                                                                                                                                                                                                                                                                                                                                    |1392076800|https://www.igdb.com/platforms/xbox   |[77]                                                       |null    |
# |X360        |X360                |1       |d61474ac-0b7c-054c-6450-9aa75ad1ad73|1297639288|7         |12 |Xbox 360                           |2              |622          |xbox360|Xbox 360 brings you a total games and entertainment experience. The largest library of games, including titles that get you right into the thick of it with Kinect. Plus, your whole family can watch HD movies, TV shows, live events, music, sports and more—across all your devices. Xbox 360 is the center of your games and entertainment universe.|1633117136|https://www.igdb.com/platforms/xbox360|[2, 3, 83, 495]                                            |[4]     |
# |DOS         |PC DOS              |4       |9aabba9b-eb06-5274-26e1-250114855890|1297672223|null      |13 |DOS                                |null           |38           |dos    |null                                                                                                                                                                                                                                                                                                                                                    |1656450592|https://www.igdb.com/platforms/dos    |[56, 540]                                                  |null    |
# |Mac         |Mac OS              |4       |19c9dcae-80a2-e137-50ff-11b823738827|1297641600|null      |14 |Mac                                |null           |100          |mac    |null                                                                                                                                                                                                                                                                                                                                                    |1394236800|https://www.igdb.com/platforms/mac    |[45, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151]|[5]     |
# |C64         |C64/C128/MAX        |6       |9a1db5f9-83b3-257e-9ae6-785a4e65d919|1297880639|null      |15 |Commodore C64/128/MAX              |null           |300          |c64    |null                                                                                                                                                                                                                                                                                                                                                    |1660212364|https://www.igdb.com/platforms/c64    |[36]                                                       |null    |
# |Amiga       |Commodore Amiga     |6       |222d007a-1c2f-94a3-e83f-94d881c00176|1297880654|null      |16 |Amiga                              |null           |null         |amiga  |null                                                                                                                                                                                                                                                                                                                                                    |1696214981|https://www.igdb.com/platforms/amiga  |[19, 109, 110, 111, 112, 113, 522]                         |null    |
# |NES         |NES                 |1       |e5286baa-27cd-f24d-bf1a-f37abb776219|1297941636|3         |18 |Nintendo Entertainment System      |5              |229          |nes    |null                                                                                                                                                                                                                                                                                                                                                    |1660212114|https://www.igdb.com/platforms/nes    |[53, 175]                                                  |null    |
# |SNES        |SNES, Super Nintendo|1       |8b2b4298-17ca-05a6-8420-26d6fca32a8a|1297941647|4         |19 |Super Nintendo Entertainment System|5              |535          |snes   |null                                                                                                                                                                                                                                                                                                                                                    |1660212083|https://www.igdb.com/platforms/snes   |[68, 95, 97, 139, 177, 391]                                |[209]   |
# |NDS         |NDS                 |5       |01ea20e3-3e12-2211-5f66-f4b631cbe59c|1297941701|7         |20 |Nintendo DS                        |5              |245          |nds    |null                                                                                                                                                                                                                                                                                                                                                    |1633117133|https://www.igdb.com/platforms/nds    |[52, 190, 191, 192]                                        |null    |
# |NGC         |GCN                 |1       |617b5b20-8ace-6046-14ed-7795ab4eb5f5|1298032543|6         |21 |Nintendo GameCube                  |5              |262          |ngc    |null                                                                                                                                                                                                                                                                                                                                                    |1644575483|https://www.igdb.com/platforms/ngc    |[54, 121, 125]                                             |[292]   |
# |GBC         |GBC                 |5       |ecd1db6f-8e22-bba6-a2d4-6b33cb5c2682|1300187960|5         |22 |Game Boy Color                     |5              |273          |gbc    |null                                                                                                                                                                                                                                                                                                                                                    |1628498928|https://www.igdb.com/platforms/gbc    |[41]                                                       |null    |
# |DC          |DC                  |1       |b746d5a7-b046-c612-1f83-0bbf8cb96500|1300188004|6         |23 |Dreamcast                          |3              |270          |dc     |null                                                                                                                                                                                                                                                                                                                                                    |1617960514|https://www.igdb.com/platforms/dc     |[16]                                                       |[276]   |
# |GBA         |GBA                 |5       |2741e85f-e65d-4668-6cdb-36fca54e5dd4|1300147200|6         |24 |Game Boy Advance                   |5              |255          |gba    |null                                                                                                                                                                                                                                                                                                                                                    |1471478400|https://www.igdb.com/platforms/gba    |[40, 193, 194]                                             |null    |
# +------------+--------------------+--------+------------------------------------+----------+----------+---+-----------------------------------+---------------+-------------+-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+--------------------------------------+-----------------------------------------------------------+--------+
# only showing top 20 rows

# %%
dfIGDB_Platforms.filter("alternative_name is null").show(truncate = False)
print(dfIGDB_Platforms.filter("alternative_name is null").count())
# Out:
# +-------------+----------------+--------+------------------------------------+----------+----------+---+----------------+---------------+-------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+--------------------------------------------+-----------------------------+--------+
# |abbreviation |alternative_name|category|checksum                            |created_at|generation|id |name            |platform_family|platform_logo|slug         |summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |updated_at|url                                         |versions                     |websites|
# +-------------+----------------+--------+------------------------------------+----------+----------+---+----------------+---------------+-------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+--------------------------------------------+-----------------------------+--------+
# |XBOX         |null            |1       |226780a3-83ed-dcf9-6757-77091acc172d|1297555200|6         |11 |Xbox            |2              |266          |xbox         |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1392076800|https://www.igdb.com/platforms/xbox         |[77]                         |null    |
# |ZXS          |null            |6       |f73944f5-3aee-6709-e02f-ed9b896a85cc|1300147200|null      |26 |ZX Spectrum     |null           |371          |zxs          |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1468540800|https://www.igdb.com/platforms/zxs          |[79]                         |null    |
# |MSX          |null            |6       |7954204a-0502-4940-48c1-d525148f76fd|1300147200|null      |27 |MSX             |null           |307          |msx          |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1468540800|https://www.igdb.com/platforms/msx          |[47]                         |null    |
# |Sega32       |null            |1       |d47b5ebe-fc4e-7719-a5d9-ad5eeebc6ede|1300924800|4         |30 |Sega 32X        |3              |279          |sega32       |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1555977600|https://www.igdb.com/platforms/sega32       |[61]                         |null    |
# |iOS          |null            |4       |fefe4a2b-7c90-0e89-e811-902ea1cf2b58|1317686400|null      |39 |iOS             |null           |248          |ios          |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1391644800|https://www.igdb.com/platforms/ios          |[43]                         |null    |
# |zod          |null            |5       |7916e6bf-353a-6f27-a8de-a429204d17d9|1317686400|null      |44 |Tapwave Zodiac  |null           |46           |zod          |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1392076800|https://www.igdb.com/platforms/zod          |[69]                         |null    |
# |VC           |null            |3       |1d9fa2f3-0e52-813a-1525-6fdfcc4c732c|1326279244|null      |47 |Virtual Console |5              |384          |vc           |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1681240385|https://www.igdb.com/platforms/vc           |[71]                         |null    |
# |Arcade       |null            |2       |3b46eb50-f62a-2a91-9b49-31c634874eca|1340047141|null      |52 |Arcade          |null           |null         |arcade       |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1693241338|https://www.igdb.com/platforms/arcade       |[22, 634, 635, 636, 637, 638]|null    |
# |MSX2         |null            |6       |d6f6cc07-f15c-1fab-6372-734d874684c8|1340064000|null      |53 |MSX2            |null           |308          |msx2         |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1468540800|https://www.igdb.com/platforms/msx2         |[48]                         |null    |
# |Lynx         |null            |5       |28a85ec7-a1de-6e5b-9373-e0bbd3bafa13|1372204800|4         |61 |Atari Lynx      |null           |290          |lynx         |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1392076800|https://www.igdb.com/platforms/lynx         |[29, 189]                    |null    |
# |Jaguar       |null            |1       |70557c0a-1cac-d093-d287-67d8e5a201b0|1372204800|5         |62 |Atari Jaguar    |null           |286          |jaguar       |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1392076800|https://www.igdb.com/platforms/jaguar       |[28]                         |null    |
# |Atari-ST     |null            |6       |34e7481c-c27b-bef7-d2cf-f2e48ffcb5d7|1372291200|null      |63 |Atari ST/STE    |null           |367          |atari-st     |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1468454400|https://www.igdb.com/platforms/atari-st     |[30]                         |null    |
# |Atari8bit    |null            |6       |37adef88-b15f-3963-a417-687e5e0a6260|1372464000|null      |65 |Atari 8-bit     |null           |373          |atari8bit    |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1468540800|https://www.igdb.com/platforms/atari8bit    |[27, 104]                    |null    |
# |intellivision|null            |1       |84a4defd-0a29-ca54-0a07-67b61a4ddc98|1372464000|2         |67 |Intellivision   |null           |312          |intellivision|null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1392076800|https://www.igdb.com/platforms/intellivision|[42]                         |null    |
# |colecovision |null            |1       |85231b96-19bb-f7cb-608b-736c5120b70f|1372464000|2         |68 |ColecoVision    |null           |311          |colecovision |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1392076800|https://www.igdb.com/platforms/colecovision |[35]                         |null    |
# |vectrex      |null            |1       |5140484a-7fd8-2a13-2542-a9207d7c9fd4|1372464000|2         |70 |Vectrex         |null           |305          |vectrex      |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1392076800|https://www.igdb.com/platforms/vectrex      |[70]                         |null    |
# |vic-20       |null            |6       |3e43a9f4-b55b-69e8-7222-64487c29bd47|1372464000|null      |71 |Commodore VIC-20|null           |313          |vic-20       |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1429142400|https://www.igdb.com/platforms/vic-20       |[37]                         |null    |
# |Ouya         |null            |1       |ec1994ca-3247-830f-8452-b664a411ade3|1373328000|8         |72 |Ouya            |null           |236          |ouya         |The Ouya (/ˈuːjə/ oo-yə), stylized OUYA, is a microconsole running its own version of the Android operating system, developed by Ouya Inc. Julie Uhrman founded the project in 2012. She brought in designer Yves Béhar to collaborate on the design of the project, and Muffi Ghadiali as product manager to put together the engineering team. Development was funded via Kickstarter, raising $8.5 million and becoming the website's second-highest-earning project in its history.\n\nUnits started to ship to Kickstarter backers on March 28, 2013. The console was released to the general public on June 25, 2013, and features an exclusive Ouya store for applications and games designed specifically for the Ouya platform, of which the majority are casual games targeted at or used by a mass audience of casual gamers. Out of the box, Ouya supports media apps such as TwitchTV and XBMC media player. It runs a modified version of Android 4.1 Jelly Bean, and is open to rooting without voiding the warranty (developer models ordered during the Kickstarter campaign for $699 or $1,337 come pre-rooted). The console's hardware design allows it to be easily opened up, requiring only a standard screwdriver for easy modding and possible hardware addons.\n\nAll systems can be used as development kits, allowing any Ouya owner to also be a developer, without the need for licensing fees. All games are required to have some kind of free-to-play aspect, whether that be completely free, has a free trial, or has purchasable upgrades, levels, or other in-game items. The Ouya is classified as part of the eighth generation of video game consoles and as such is a rival competing against the PlayStation 4, Xbox One, and Wii U.|1438905600|https://www.igdb.com/platforms/ouya         |[55]                         |[13]    |
# |blackberry   |null            |4       |6fdda0e4-4884-2e33-fd1a-de3521c9b804|1384387200|null      |73 |BlackBerry OS   |null           |40           |blackberry   |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1392076800|https://www.igdb.com/platforms/blackberry   |[34]                         |null    |
# |x1           |null            |6       |c3265f1f-9c3e-fc18-b8e9-cf288b499e95|1390867200|null      |77 |Sharp X1        |null           |297          |x1           |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |1468454400|https://www.igdb.com/platforms/x1           |[66]                         |null    |
# +-------------+----------------+--------+------------------------------------+----------+----------+---+----------------+---------------+-------------+-------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+--------------------------------------------+-----------------------------+--------+
# only showing top 20 rows
#
# 97

# %%
# Exibe o Schema do DataFrame
dfIGDB_Platforms.printSchema()
# Out:
# root
#  |-- abbreviation: string (nullable = true)
#  |-- alternative_name: string (nullable = true)
#  |-- category: long (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- generation: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- platform_family: long (nullable = true)
#  |-- platform_logo: long (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- url: string (nullable = true)
#  |-- versions: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- websites: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
dfIGDB_Platforms.count()
# Out:
# 200

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_Platforms = (dfIGDB_Platforms
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Exploração

# %%
dfPlatformsByCategory = (dfIGDB_Platforms
                         .select("id", "category")
                         .groupby("category")
                         .agg(fn.count("id").alias("platforms"))
                         .orderBy(fn.col("category").desc())
                        )

delta_table_path = 's3a://raw/igdb_enums/platforms/category/delta/'

dfIGDB_Platform_Categories = DeltaTable.forPath(spark, delta_table_path).toDF()

total_plats = dfPlatformsByCategory.agg(fn.sum("platforms")).collect()[0][0]

(dfPlatformsByCategory
 .join(dfIGDB_Platform_Categories, dfPlatformsByCategory.category == dfIGDB_Platform_Categories.value, how="left")
 .withColumn("category", fn.when(fn.col("category").isNull(), "Undefined")
                             .otherwise(fn.col("name")))
 .withColumn("Percent", fn.round(((fn.col("platforms") / total_plats) * 100), 2))
 .select(fn.col("category").alias("Categories"), fn.col("platforms").alias("Platforms"), "Percent")
 .orderBy(fn.col("Platforms").desc())
).show(truncate=False)
# Out:
# +----------------+---------+-------+
# |Categories      |Platforms|Percent|
# +----------------+---------+-------+
# |console         |80       |40.0   |
# |computer        |55       |27.5   |
# |portable_console|34       |17.0   |
# |operating_system|10       |5.0    |
# |Undefined       |10       |5.0    |
# |platform        |8        |4.0    |
# |arcade          |3        |1.5    |
# +----------------+---------+-------+

# %%
# Número de Games por Plataforma (considerando multi-classificação)
dfGamesByPlatform = (dfIGDB_Games
 .select("id", fn.explode_outer("platforms").alias("platform_id"))
 .groupBy("platform_id")
 .agg(fn.count("id").alias("games"))
 .orderBy("platform_id")
)

total_titles = dfGamesByPlatform.agg(fn.sum("games")).collect()[0][0]

(dfGamesByPlatform
 .join(dfIGDB_Platforms, dfGamesByPlatform.platform_id == dfIGDB_Platforms.id, how="left")
 .withColumn("name", fn.when(fn.col("name").isNull(), "Undefined")
                             .otherwise(fn.col("name")))
 .withColumn("Percent", fn.round(((fn.col("Games") / total_titles) * 100), 2))
 .select(fn.col("name").alias("Platforms"), fn.col("games").alias("Games"), "Percent")
 .orderBy(fn.col("Games").desc())
).show(truncate=False)
# Out:
# +----------------------+-----+-------+
# |Platforms             |Games|Percent|
# +----------------------+-----+-------+
# |PC (Microsoft Windows)|94060|26.09  |
# |Undefined             |81010|22.47  |
# |Mac                   |20452|5.67   |
# |Nintendo Switch       |14773|4.1    |
# |iOS                   |12768|3.54   |
# |PlayStation 4         |12453|3.45   |
# |Linux                 |12354|3.43   |
# |Android               |10328|2.87   |
# |Xbox One              |10245|2.84   |
# |Web browser           |5719 |1.59   |
# |PlayStation 3         |3954 |1.1    |
# |PlayStation 5         |3896 |1.08   |
# |Arcade                |3687 |1.02   |
# |PlayStation 2         |3653 |1.01   |
# |Xbox Series X|S       |3543 |0.98   |
# |Xbox 360              |3395 |0.94   |
# |DOS                   |3362 |0.93   |
# |PlayStation           |3084 |0.86   |
# |Wii                   |2770 |0.77   |
# |Commodore C64/128/MAX |2601 |0.72   |
# +----------------------+-----+-------+
# only showing top 20 rows

# %% [markdown]
# ## Platform Families

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'platform_families'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Platform_Families = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Platform_Families.show(20, truncate=False)
# Out:
# +------------------------------------+---+-----------+-----------+
# |checksum                            |id |name       |slug       |
# +------------------------------------+---+-----------+-----------+
# |eadc0208-7972-9364-88b9-d2a9de75a998|1  |PlayStation|playstation|
# |5bb9bcec-4aa7-45b8-129b-a6f88932942e|2  |Xbox       |xbox       |
# |bd1a9cc4-3632-33b0-ff4b-feab8cd15001|3  |Sega       |sega       |
# |be8b89fa-823c-790a-1d5a-7e74315c1b27|4  |Linux      |linux      |
# |398e5c87-f7db-6265-6da6-433441385208|5  |Nintendo   |nintendo   |
# +------------------------------------+---+-----------+-----------+

# %%
# Exibe o Schema do DataFrame
dfIGDB_Platform_Families.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)

# %%
dfIGDB_Platform_Families.count()
# Out:
# 5

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# ## Platform Logos

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'platform_logos'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Platform_Logos = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Platform_Logos.show(20, truncate=False)
# Out:
# +-------------+--------+------------------------------------+------+---+--------------------+--------------------------------------------------------------------+-----+
# |alpha_channel|animated|checksum                            |height|id |image_id            |url                                                                 |width|
# +-------------+--------+------------------------------------+------+---+--------------------+--------------------------------------------------------------------+-----+
# |true         |false   |7ab4aaa1-c6bf-e8b3-1db1-7ff668132f10|1000  |38 |sqgw6vespav1buezgjjn|//images.igdb.com/igdb/image/upload/t_thumb/sqgw6vespav1buezgjjn.jpg|1000 |
# |false        |false   |2081ddfe-e71f-6d54-e758-4bdf9520af6b|174   |40 |bezbkk17hk0uobdkhjcv|//images.igdb.com/igdb/image/upload/t_thumb/bezbkk17hk0uobdkhjcv.jpg|1000 |
# |true         |false   |be0be98a-a023-52c7-bf1d-7409c4c8179f|700   |42 |lz0cuozrdeealg8hfzxg|//images.igdb.com/igdb/image/upload/t_thumb/lz0cuozrdeealg8hfzxg.jpg|700  |
# |false        |false   |254ff507-952d-085e-b5b1-bcc36ce36797|99    |46 |lfsdnlko80ftakbugceu|//images.igdb.com/igdb/image/upload/t_thumb/lfsdnlko80ftakbugceu.jpg|400  |
# |false        |false   |1fbdfde1-6d39-fff3-8606-307147195dd0|170   |49 |hrmqljpwunky1all3v78|//images.igdb.com/igdb/image/upload/t_thumb/hrmqljpwunky1all3v78.jpg|210  |
# |false        |false   |b70ff9db-26d7-6d00-2906-682d531134a4|242   |58 |gvskesmuwhvmtzv2zhny|//images.igdb.com/igdb/image/upload/t_thumb/gvskesmuwhvmtzv2zhny.jpg|260  |
# |false        |false   |62890ec1-709d-0828-1886-7ecfecc17bca|577   |59 |w4okoupqnolhrymeqznd|//images.igdb.com/igdb/image/upload/t_thumb/w4okoupqnolhrymeqznd.jpg|577  |
# |false        |false   |5108ce87-d122-e968-79d5-c6e18eefeea2|450   |60 |fxe5fcitcfmnam128xc1|//images.igdb.com/igdb/image/upload/t_thumb/fxe5fcitcfmnam128xc1.jpg|600  |
# |true         |false   |64ede0f5-cc64-5fbb-eefe-ee7068398220|420   |61 |qkdxwfyrcwhqrnj1hljd|//images.igdb.com/igdb/image/upload/t_thumb/qkdxwfyrcwhqrnj1hljd.jpg|550  |
# |false        |false   |fa44fd1a-f94a-1647-c024-dfc254902ec6|331   |62 |iftbsii6snn6geq5hi9n|//images.igdb.com/igdb/image/upload/t_thumb/iftbsii6snn6geq5hi9n.jpg|277  |
# |true         |false   |428975da-af47-1cb4-0e92-9f6e99558a78|487   |63 |kb9wpjpv0t1dthhuypou|//images.igdb.com/igdb/image/upload/t_thumb/kb9wpjpv0t1dthhuypou.jpg|326  |
# |true         |false   |f0325fd7-0a80-03c2-3808-a3520e642f16|340   |66 |m7lor1sj7g9gnvliwxx8|//images.igdb.com/igdb/image/upload/t_thumb/m7lor1sj7g9gnvliwxx8.jpg|1384 |
# |true         |false   |fc5f89cf-d64c-3e7c-1ea1-5754b46f7c88|412   |69 |hamfdrgnhenxb2d9g8mh|//images.igdb.com/igdb/image/upload/t_thumb/hamfdrgnhenxb2d9g8mh.jpg|412  |
# |true         |false   |d614a66b-393e-2a23-33d2-a8c5fd1366db|412   |70 |cbhfilmhdgwdql8nzsy0|//images.igdb.com/igdb/image/upload/t_thumb/cbhfilmhdgwdql8nzsy0.jpg|412  |
# |false        |false   |662d110d-9f11-6716-7949-c939b8a47ad4|125   |71 |mr2y5qpyhvj1phm5tivg|//images.igdb.com/igdb/image/upload/t_thumb/mr2y5qpyhvj1phm5tivg.jpg|500  |
# |false        |false   |2c9fd4ed-b5c3-8218-9b7b-c08c985e38c4|125   |73 |ob1omu1he33vpulatqzv|//images.igdb.com/igdb/image/upload/t_thumb/ob1omu1he33vpulatqzv.jpg|500  |
# |true         |false   |d32b22e3-da4c-2b80-498f-0e08eaaa9ed2|358   |74 |a9x7xjy4p9sqynrvomcf|//images.igdb.com/igdb/image/upload/t_thumb/a9x7xjy4p9sqynrvomcf.jpg|500  |
# |false        |false   |6d4e051d-bcb1-4d78-5d5f-5aacdb746a25|269   |79 |tuyy1nrqodtmbqajp4jg|//images.igdb.com/igdb/image/upload/t_thumb/tuyy1nrqodtmbqajp4jg.jpg|640  |
# |true         |false   |993a3809-e174-e5db-c209-f3727037fd2e|966   |87 |jtbbevwj5l6q01pkkned|//images.igdb.com/igdb/image/upload/t_thumb/jtbbevwj5l6q01pkkned.jpg|1600 |
# |false        |false   |2818dae3-5bfb-7d28-117a-5225523feec3|95    |89 |eatvxlflfq0lk8p8sp2c|//images.igdb.com/igdb/image/upload/t_thumb/eatvxlflfq0lk8p8sp2c.jpg|70   |
# +-------------+--------+------------------------------------+------+---+--------------------+--------------------------------------------------------------------+-----+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_Platform_Logos.printSchema()
# Out:
# root
#  |-- alpha_channel: boolean (nullable = true)
#  |-- animated: boolean (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- height: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- image_id: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- width: long (nullable = true)

# %%
dfIGDB_Platform_Logos.count()
# Out:
# 346

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'platform_versions'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Platform_Versions = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Platform_Versions.show(20, truncate=False)
# Out:
# +------------------------------------+----------+-------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------+---+-----------------+----------------------------------------------------------------------------------------------------------------+-----------------------------------------+------------------------+----------------------------+-------------------------------------------------------------+-----------------------------------------------------------+-------------+------------------------------+-----------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------+---------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |checksum                            |companies |connectivity                                                       |cpu                                            |graphics                                           |id |main_manufacturer|media                                                                                                           |memory                                   |name                    |online                      |os                                                           |output                                                     |platform_logo|platform_version_release_dates|resolutions                                                                                                                        |slug                                                |sound                                                          |storage                                           |summary                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# +------------------------------------+----------+-------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------+---+-----------------+----------------------------------------------------------------------------------------------------------------+-----------------------------------------+------------------------+----------------------------+-------------------------------------------------------------+-----------------------------------------------------------+-------------+------------------------------+-----------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------+---------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |81bcc19f-8798-d0bc-6dd4-4296542563d6|[247]     |null                                                               |null                                           |null                                               |1  |null             |null                                                                                                            |null                                     |Windows 7               |null                        |null                                                         |null                                                       |207          |[259]                         |null                                                                                                                               |windows-7                                           |null                                                           |null                                              |Unlike Windows Vista's many new features, Windows 7 was an incremental upgrade designed to work with Vista-compatible applications and hardware. Presentations given by Microsoft in 2008 focused on multi-touch support, an updated Windows shell with a new taskbar, referred to internally as the Superbar, a home networking system called HomeGroup, and performance improvements.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# |69224598-256a-3ff9-a345-bd704a9e2148|null      |null                                                               |null                                           |null                                               |2  |null             |null                                                                                                            |null                                     |Xbox 360 Elite          |null                        |null                                                         |null                                                       |251          |null                          |null                                                                                                                               |xbox-360-elite                                      |null                                                           |null                                              |Xbox 360 brings you a total games and entertainment experience. The largest library of games, including titles that get you right into the thick of it with Kinect. Plus, your whole family can watch HD movies, TV shows, live events, music, sports and more—across all your devices. Xbox 360 is the center of your games and entertainment universe.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# |8b9f5a93-4afe-405c-3046-bc3fb538f82d|null      |null                                                               |null                                           |null                                               |3  |null             |null                                                                                                            |null                                     |Xbox 360 Arcade         |null                        |null                                                         |null                                                       |250          |[2]                           |null                                                                                                                               |xbox-360-arcade                                     |null                                                           |null                                              |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |f8808442-b044-1882-a33e-e57f5920c936|null      |Wi-Fi IEEE 802.11 b/g. Bluetooth 2,0 and 2x USB 2,0, Ethernet      |3,2 GHz Cell Broadband Engine                  |550 MHz nVidia/SCEI RSX ''Reality Synthesizer''    |4  |null             |Blu-ray, DVD, Compact Disc, Playstation Game disc, Playstation 2 game disc, Super Audio CD, Digital distribution|256 MB system, 256 MB video              |Playstation 3 Original  |Playstation Network         |XcrossMediaBar                                               |null                                                       |237          |[3, 4, 5]                     |480i, 480p, 720p, 1080i, 1080p                                                                                                     |playstation-3-original                              |Dolby Digital, DTS                                             |20 GB, 40 GB, 60 GB, 80 GB, 120 GB                |Launch model released in 2006, commonly known as the PS3 Fat                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# |230fa32c-1d27-0d06-f911-a243429bb192|[295]     |Wi-Fi IEEE 802.11 b/g. Bluetooth 2,0 and 2x USB 2,0, Ethernet      |3,2 GHz Cell Broadband Engine                  |550 MHz nVidia/SCEI RSX ''Reality Synthesizer''    |5  |null             |Blu-ray, DVD, Compact Disc, Playstation Game disc, Digital distribution                                         |256 MB system, 256 MB video              |Playstation 3 Slim      |Playstation Network         |XcrossMediaBar                                               |S-Video, RGB Scart, YPAPR, D-Terminal, HDMI                |238          |[165, 166, 167]               |480i, 480p, 720p, 1080i, 1080p                                                                                                     |playstation-3-slim                                  |Dolby Digital, DTS, DTS-HD Master Audio, Dolby TrueHD          |120 GB, 250 GB                                    |Released in 2009 as an slimmer, quieter and re-designet version of the PS3. They also changed the font from the ''Spider-Man'' like PLAYSTATION 3 design to a more traditional Playstation look while also imprinting PS3 on the console surface instead of PLAYSTATION 3.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# |50fa2235-a2d7-ac43-3931-bf6e083c69e7|[74]      |null                                                               |null                                           |null                                               |6  |null             |null                                                                                                            |null                                     |Playstation 3 Super Slim|null                        |null                                                         |null                                                       |79           |[161, 162, 163, 164]          |null                                                                                                                               |playstation-3-super-slim                            |null                                                           |null                                              |In September 2012, Sony announced that a new slimmer PS3 redesign (CECH-4000) was due to be released in late 2012 and that it would be available with either a 250 GB or 500 GB hard drive. In PAL regions, the 250 GB model is not available; a model with 12 GB of flash memory is available in its place. A standalone 250 GB hard drive is available to upgrade this model. Both are roughly 25% smaller and about 20% lighter than the original PS3 Slim. This version has a sliding disc cover rather than the slot-loading drive found on previous PlayStation 3 consoles. A vertical stand is also available for these models and was launched on the same day as the consoles in their respective regions.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# |8f9379a2-925e-98fd-0b18-b050120d3f6a|[55]      |null                                                               |null                                           |null                                               |7  |null             |null                                                                                                            |null                                     |Froyo 2.2               |null                        |null                                                         |null                                                       |58           |[106]                         |null                                                                                                                               |froyo-2-2                                           |null                                                           |null                                              |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# |5dc8a075-11ed-40c1-6c88-a82d92cac368|[59]      |null                                                               |null                                           |null                                               |8  |null             |null                                                                                                            |null                                     |Gingerbread 2.3.3       |null                        |null                                                         |null                                                       |62           |[110]                         |null                                                                                                                               |gingerbread-2-3-3                                   |null                                                           |null                                              |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# ...
# |9cf35e31-01b1-da5e-22be-7baa27c8fe9e|null      |null                                                               |Motorola 68000 @ 7.16 MHz (NTSC) 7.09 MHz (PAL)|null                                               |19 |null             |880 kB floppy disks                                                                                             |512 kB (9 MB maximum)                    |Amiga A 500             |null                        |AmigaOS v1.2 - 1.3                                           |null                                                       |391          |[134]                         |736x567i 4-bpp PAL (736x483i 4 bpp NTSC), 368x567i 6 bpp PAL (368x483i 6 bpp NTSC)                                                 |amiga-a-500                                         |4× 8-bit channels PCM at max 28 kHz with 6-bit volume in stereo|null                                              |In 1982, the Amiga Corporation developed "Lorraine" a computer that was named after the wife of the company's president. Amiga incorporated a 16-bit 68000 chip as Lorraine's CPU. Lorraine featured two dedicated graphics and sound chips.\n\nBy the time Lorraine was introduced at the Consumer Electronics Show on January 4, 1984, the developmental costs that Amiga had devoted to it had exceeded its resources. After Atari showed interest in purchasing the company, Commodore stepped in to outbid the console giant and renamed the system the Amiga.\n\nCommodore made some slight modifications to the Amiga. The system's memory was upgraded to 256KB and the console was redesigned to accommodate keyboard storage underneath it. Commodore finally released the Amiga 1000 in July 1985 at a retail price of $1,295. It was compatible with home television sets and could be utilized for video editing. It featured a palette of 4,096 colors and was capable of 320 x 200 resolution. The system also featured a 3.5 inch floppy disk drive that could externally store up to 880KB.\n\nThe "Paula" sound chip enabled programs to be heard in stereo. The system featured two mouse/controller ports. Such peripherals as joysticks, light pens or game paddles could be used with the system. Even in its early stages of release, Commodore chose to promote the Amiga as a game machine.\n\nThe "kickstart" was a small part of the operating system that was contained in the ROM. The Amiga performed a kickstart or initiated the loading of the operating system itself every time the computer was activated. To fully load the operating system a 3.5 inch AmigaDos disk needed to be inserted into the external drive. Every time the computer was shut off, the operating system was lost from memory and needed to be reloaded.\n\nThe Amiga 1000 was capable of "multitasking." A concept similar to Windows 95, multitasking allowed users to keep two or more programs open at one time and instantly switch between them. The "Workbench" was the Amiga's file manager. Workbench allowed users to open windows and run programs.\n\nIn 1987, Commodore released the Amiga 500 and the Amiga 2000. The Amiga 500 was a compact system that became the best selling computer in the Amiga line. Among the improvements Commodore incorporated into the Amiga 500 were an updated operating system (AmigaDOS 1.2), 512KB RAM and a bigger keyboard. The Amiga 2000 featured a new computer case design, expansion slots and a CPU slot for future processor upgrades. It was powered by a 68000 microprocessor.\n\nThe Amiga 3000 improved on the Amiga 2000 by offering new Zorro III expansion slots, an integrated SCSI interface and a built-in hard drive. It used a 68030 32-bit microprocessor and a new version of Workbench.\n\nIn 1992 Commodore released the Amiga 600. Commodore promoted the system as a video game console with a keyboard. It quickly vanished from store shelves. Later that year Commodore released the Amiga 4000 and the Amiga 1200. The 4000 featured the speedy 68040 processor. It could display up to 256,000 colors on-screen  ...
# |57b5ae47-0ced-9743-3eb9-a7728a6c064e|[624]     |null                                                               |Zilog Z80A @ 4 MHz                             |null                                               |20 |null             |null                                                                                                            |64 or 128 KB                             |CPC 464                 |null                        |AMSDOS                                                       |null                                                       |114          |[641]                         |null                                                                                                                               |cpc-464                                             |null                                                           |null                                              |The Amstrad CPC (short for Colour Personal Computer) is a series of 8-bit home computers produced by Amstrad between 1984 and 1990. It was designed to compete in the mid-1980s home computer market dominated by the Commodore 64 and the Sinclair ZX Spectrum, where it successfully established itself primarily in the United Kingdom, France, Spain, and the German-speaking parts of Europe.\n\nThe series spawned a total of six distinct models: The CPC464, CPC664, and CPC6128 were highly successful competitors in the European home computer market. The later 464plus and 6128plus, intended to prolong the system's lifecycle with hardware updates, were considerably less successful, as was the attempt to repackage the plus hardware into a game console as the GX4000.\n\nThe CPC models' hardware is based on the Zilog Z80A CPU, complemented with either 64 or 128 KB of RAM. Their computer-in-a-keyboard design prominently features an integrated storage device, either a compact cassette deck or 3-inch floppy disk drive. The main units were only sold bundled with either a colour, green-screen or monochrome monitor that doubles as the main unit's power supply. Additionally, a wide range of first and third-party hardware extensions such as external disk drives, printers, and memory extensions, was available.\n\nThe CPC series was pitched against other home computers primarily used to play video games and enjoyed a strong supply of game software. The comparatively low price for a complete computer system with dedicated monitor, its high-resolution monochrome text and graphic capabilities and the possibility to run CP/M software also rendered the system attractive for business users, which was reflected by a wide selection of application software.\n\nDuring its lifetime, the CPC series sold approximately three million units.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# +------------------------------------+----------+-------------------------------------------------------------------+-----------------------------------------------+---------------------------------------------------+---+-----------------+----------------------------------------------------------------------------------------------------------------+-----------------------------------------+------------------------+----------------------------+-------------------------------------------------------------+-----------------------------------------------------------+-------------+------------------------------+-----------------------------------------------------------------------------------------------------------------------------------+----------------------------------------------------+---------------------------------------------------------------+--------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_Platform_Versions.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- companies: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- connectivity: string (nullable = true)
#  |-- cpu: string (nullable = true)
#  |-- graphics: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- main_manufacturer: long (nullable = true)
#  |-- media: string (nullable = true)
#  |-- memory: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- online: string (nullable = true)
#  |-- os: string (nullable = true)
#  |-- output: string (nullable = true)
#  |-- platform_logo: long (nullable = true)
#  |-- platform_version_release_dates: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- resolutions: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- sound: string (nullable = true)
#  |-- storage: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_Platform_Versions.count()
# Out:
# 371

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'platform_version_companies'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Platform_Version_Companies = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Platform_Version_Companies.show(20, truncate=False)
# Out:
# +------------------------------------+-------+-------+---------+---+------------+
# |checksum                            |comment|company|developer|id |manufacturer|
# +------------------------------------+-------+-------+---------+---+------------+
# |459b2566-8c93-57b1-7b6f-13f539e2684e|null   |2123   |false    |1  |true        |
# |17ea4f71-e7e1-6ee5-fd36-35a72762387a|null   |45     |true     |2  |false       |
# |9b310657-674c-6e9c-98d9-12fc245d2e82|null   |128    |true     |3  |false       |
# |e9b66b9f-679c-5d39-2c9e-a50e65deb5c1|null   |2348   |false    |4  |true        |
# |c007c51b-85b7-f1d5-c013-2f4d849663c1|null   |2123   |false    |5  |true        |
# |43332237-22ed-fc58-1078-1ee0ddff5412|null   |128    |true     |6  |false       |
# |a87b2e66-b677-57a0-6d0b-2890515d8e8f|null   |2350   |true     |7  |true        |
# |36293e0a-e673-eedf-9f0f-4821b6addeb7|null   |128    |true     |8  |false       |
# |b9760e01-3fa2-2738-1e23-5153c5ecfe3d|null   |128    |true     |9  |false       |
# |fac9909c-5324-e1d3-8343-fd00507331d4|null   |128    |true     |10 |false       |
# |263eb0d4-df1e-10f2-55ba-a74db1b82ef8|null   |70     |false    |11 |true        |
# |7614e0b2-987a-ee3b-7cc3-4bf1d99b74c2|null   |112    |false    |12 |true        |
# |bba32c8b-af64-543a-b592-5efa0a5b5b22|null   |45     |false    |13 |true        |
# |ef49561c-d9e8-8e28-8121-bf21824b70c9|null   |128    |true     |14 |true        |
# |5ce941ae-e045-b37e-ee76-890c11bccfd9|null   |2348   |false    |15 |true        |
# |008bdc61-52d3-2bf3-deb3-a2bb1a09cd81|null   |128    |true     |16 |false       |
# |89f86c07-ecea-19a2-a2c4-dd68e595e3b8|null   |82     |false    |17 |true        |
# |249dcdb4-33f4-4d84-60b0-86ff78640b49|null   |70     |false    |18 |true        |
# |516f53d0-220b-3724-dfc9-dbad1ec9b77d|null   |1778   |true     |19 |false       |
# |258839b0-089f-f447-db52-58d5951a62e7|null   |45     |false    |20 |true        |
# +------------------------------------+-------+-------+---------+---+------------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_Platform_Version_Companies.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- comment: string (nullable = true)
#  |-- company: long (nullable = true)
#  |-- developer: boolean (nullable = true)
#  |-- id: long (nullable = true)
#  |-- manufacturer: boolean (nullable = true)

# %%
dfIGDB_Platform_Version_Companies.count()
# Out:
# 548

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'platform_version_release_dates'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Platform_Version_Release_Dates = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Platform_Version_Release_Dates.show(20, truncate=False)
# Out:
# +--------+------------------------------------+----------+------------+---+---+------+----------+----+
# |category|checksum                            |date      |human       |id |m  |region|updated_at|y   |
# +--------+------------------------------------+----------+------------+---+---+------+----------+----+
# |0       |b9365483-40a2-88ab-be8b-c20179db08f8|1256169600|Oct 22, 2009|1  |10 |8     |null      |2009|
# |0       |e8d503b7-ff48-b5a0-2549-3e1abca5bfed|1193097600|Oct 23, 2007|2  |10 |2     |null      |2007|
# |1       |4009b066-27fb-68d5-5b9d-f4ebbc0fd73a|1162339200|Nov 2006    |3  |11 |5     |null      |2006|
# |0       |28c79b81-312f-c1c7-dafa-7a9b84b9fc96|1142467200|Mar 16, 2006|4  |3  |1     |null      |2006|
# |0       |499becde-17c2-9ce3-3619-6e657635c93f|1143072000|Mar 23, 2006|5  |3  |3     |null      |2006|
# |0       |e0dd767f-af1f-f9c1-43e3-1c1f55ce57b6|1351209600|Oct 26, 2012|6  |10 |8     |null      |2012|
# |0       |766e141d-7004-df40-93ea-4946003093de|1170115200|Jan 30, 2007|7  |1  |8     |null      |2007|
# |0       |b0dde063-d97a-0755-e580-531dc5dd4e54|1003968000|Oct 25, 2001|8  |10 |8     |null      |2001|
# |0       |c09dba04-bfb8-a21a-4bf2-012e2d7759e5|1384473600|Nov 15, 2013|10 |11 |2     |null      |2013|
# |0       |531645fd-bb06-bd74-73b8-f31a0e0eb2b2|1385683200|Nov 29, 2013|11 |11 |1     |null      |2013|
# |0       |36b59c12-e49e-01a3-3ab0-5f7db48d93a9|1385683200|Nov 29, 2013|12 |11 |3     |null      |2013|
# |0       |1cf11f53-ea48-91c4-4edf-fa987c1325bf|1385683200|Nov 29, 2013|13 |11 |4     |null      |2013|
# |0       |b5734870-8833-3c82-5a73-e63c80f7bf91|1385078400|Nov 22, 2013|14 |11 |8     |null      |2013|
# |0       |432a623c-eba9-b2fe-09ed-1143e340a59f|1372118400|Jun 25, 2013|15 |6  |8     |null      |2013|
# |0       |d4614cb1-ce11-b980-f50a-d07da4b1a7f9|1353196800|Nov 18, 2012|16 |11 |8     |null      |2012|
# |0       |19fa575d-3f98-9c2f-576f-13e27246a47a|659145600 |Nov 21, 1990|17 |11 |5     |null      |1990|
# |0       |84b91429-11a2-855c-b3b3-17ba7643ae74|682905600 |Aug 23, 1991|18 |8  |2     |null      |1991|
# |0       |abdcc892-673a-bb31-843a-3ce19239223e|710380800 |Jul 06, 1992|19 |7  |1     |null      |1992|
# |0       |be86032c-545a-8090-d9c3-71a07b32f1d3|710121600 |Jul 03, 1992|20 |7  |3     |null      |1992|
# |0       |e4f46fc9-6f80-1836-82c8-1bf4b9b83403|691545600 |Dec 01, 1991|21 |12 |5     |null      |1991|
# +--------+------------------------------------+----------+------------+---+---+------+----------+----+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_Platform_Version_Release_Dates.printSchema()
# Out:
# root
#  |-- category: long (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- date: long (nullable = true)
#  |-- human: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- m: long (nullable = true)
#  |-- region: long (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- y: long (nullable = true)

# %%
dfIGDB_Platform_Version_Release_Dates.count()
# Out:
# 487

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'platform_websites'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Platform_Websites = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Platform_Websites.show(20, truncate=False)
# Out:
# +--------+------------------------------------+---+-------+---------------------------------------------------+
# |category|checksum                            |id |trusted|url                                                |
# +--------+------------------------------------+---+-------+---------------------------------------------------+
# |1       |8d6e5c1c-e1ac-20aa-87e7-6a5222df7138|1  |false  |http://www.linux.org                               |
# |1       |bedd3276-c425-1fb8-8177-ab106986b4e0|2  |false  |http://windows.microsoft.com/                      |
# |1       |eba95370-74ac-e96a-c3a0-cedd1f664e74|3  |false  |http://us.playstation.com/ps3/                     |
# |1       |58fa5f13-95e2-e504-b8c1-1ca1a65ffe66|4  |false  |http://www.xbox.com/en-US/xbox-360                 |
# |1       |bf8b0ec9-4d7a-a954-5630-071035fbd9f8|5  |false  |https://www.apple.com/osx/                         |
# |1       |f52efdbb-400a-1f74-d2eb-7d837ed5b266|6  |false  |https://sega.jp/history/hard/segasaturn/           |
# |1       |f39cdc12-2773-e427-d5ca-657052af44a2|7  |false  |http://www.android.com/                            |
# |1       |d360c282-b9dc-1853-4821-6917315e8195|9  |false  |http://www.nintendo.com/3ds                        |
# |1       |8116844b-69ab-5eef-6b46-a9939045acd7|10 |false  |http://www.nintendo.com/wiiu/                      |
# |1       |26ed8c05-4b9b-0ee2-dc5a-fa1410a3752a|11 |false  |http://www.playstation.com/ps4/                    |
# |1       |19e073e7-8de1-79d6-1c3d-8f4cfb8a3b46|12 |false  |http://www.xbox.com/en-US/xbox-one                 |
# |1       |2acd02d0-6425-77fa-96a5-3b3a5d12d69d|13 |false  |https://www.ouya.tv/                               |
# |1       |43be64f3-fa92-5876-6943-2986f89f6725|15 |false  |http://onlive.com                                  |
# |1       |1d312059-e047-2ad2-17bd-548b044d3ddc|16 |false  |http://www.nintendo.com/switch                     |
# |1       |735dd19e-13a8-1921-dddc-259e3bb340ef|17 |false  |https://www.nintendo.com/3ds/new-nintendo-3ds      |
# |1       |b33b8c70-e096-2eec-604a-ddf07847f9f1|18 |false  |http://www.vc4000.de/                              |
# |1       |7fe3ce38-7ffe-bfab-5398-73399f81fc4c|19 |false  |https://en.wikipedia.org/wiki/TRS-80_Color_Computer|
# |1       |f39bb7d2-ec5e-a96e-3d67-84bb94332090|20 |false  |https://en.wikipedia.org/wiki/FM-7                 |
# |1       |2afced08-d0f3-8559-ca10-b3d397401695|21 |false  |https://en.wikipedia.org/wiki/Dragon_32/64         |
# |1       |38a3d1e5-fd45-762c-e268-e4f429107afb|22 |false  |https://en.wikipedia.org/wiki/Amstrad_PCW          |
# +--------+------------------------------------+---+-------+---------------------------------------------------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_Platform_Websites.printSchema()
# Out:
# root
#  |-- category: long (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- trusted: boolean (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_Platform_Websites.count()
# Out:
# 101

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# ## External Games

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'external_games'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_ExtGames = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_ExtGames.show(truncate=False)
# Out:
# +--------+------------------------------------+----------+-----+---+---------------------------------------------------------------+------+----------+----+----+
# |category|checksum                            |created_at|game |id |name                                                           |uid   |updated_at|url |year|
# +--------+------------------------------------+----------+-----+---+---------------------------------------------------------------+------+----------+----+----+
# |1       |e31731d6-678a-31e0-837b-7749db2f03b0|1494460800|28590|1  |Crappy Day Enhanced Edition                                    |636700|1494547200|null|null|
# |1       |2e9851e5-0312-b3ca-abe1-e844a38d1da3|1494493232|28591|2  |Zombie Kill                                                    |636430|1633092888|null|null|
# |1       |efbc0b6c-aa73-e43a-f587-11108f326d91|1494493238|28592|3  |Tesla vs Lovecraft                                             |636100|1643444761|null|null|
# |1       |e61c5382-0391-5a75-0a1c-e9d86a49ca21|1494493300|28593|4  |EMPORIUM                                                       |635670|1643471802|null|null|
# |1       |b8005670-a895-decb-3826-fceb83a60eb0|1494493310|28594|5  |Phantasmat: The Endless Night Collector's Edition              |635520|1633080764|null|null|
# |1       |0c33e520-9bb9-b3fc-d09e-95fa200776d9|1494493323|28595|6  |Puppy Doge VR                                                  |635190|1633081919|null|null|
# |1       |1c264d0b-9f8a-7ce1-3122-9f2d17dc415c|1494493327|28596|7  |Freeze Climbing                                                |635040|1633079456|null|null|
# |1       |ef0f8178-6a09-be51-c7c8-c60e58c33eb2|1494493336|28597|8  |PLUTONIUM                                                      |634700|1633087560|null|null|
# |1       |b933f670-a71c-2e96-e34f-24d0fd481e5a|1494493354|36500|13 |Tanks vs Aliens                                                |634200|1643847986|null|null|
# |1       |3e90ba8e-e5f3-9589-cc99-ecdf33fadec7|1494493370|22038|14 |Creatures Such as We                                           |633600|1633081598|null|null|
# |1       |ec613e95-d0fc-2fd6-7d40-b8ba4ce11cbf|1494493377|36451|15 |Neighbourhood Necromancer                                      |633580|1643844006|null|null|
# |1       |049b0ee8-331d-e1d8-7a09-7b7278b3dbac|1494460800|36499|18 |Nongünz                                                        |633130|1495843200|null|null|
# |1       |07930396-ee79-fc61-d3fd-a8a3616a1db6|1494460800|36498|21 |ShineG In The Bullethell                                       |632640|1495843200|null|null|
# |1       |6ed284f1-3a90-9f26-3926-788fd76cdb2c|1494493469|36497|22 |Blockle                                                        |632510|1633079923|null|null|
# |1       |645bedc1-90e6-73de-014d-60b628c360fb|1494493489|36496|23 |The Grand Ball                                                 |632290|1633081685|null|null|
# |1       |cbe18828-19ef-cf97-78af-f1f9045540c2|1494493502|36495|25 |Remember, Remember                                             |631990|1633093013|null|null|
# |1       |5d94518b-b411-d7e6-8b72-aea52d7b63a3|1494493506|27282|26 |Immortal Planet                                                |631980|1633088875|null|null|
# |1       |0fbbd95f-d824-0fdb-2a28-ad0dd1af309c|1494493555|36494|27 |Pixplode                                                       |631770|1633080107|null|null|
# |1       |6fb71fad-3b24-5d66-d761-554e1f419550|1494493585|36493|28 |Redemption Cemetery: The Island of the Lost Collector's Edition|631280|1633077485|null|null|
# |1       |71438f89-a8e7-27f8-782f-405be43ab08b|1494493589|36450|29 |Haunted Hotel II: Believe the Lies                             |631270|1643865441|null|null|
# +--------+------------------------------------+----------+-----+---+---------------------------------------------------------------+------+----------+----+----+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_ExtGames.printSchema()
# Out:
# root
#  |-- category: long (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- game: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- uid: string (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- url: string (nullable = true)
#  |-- year: long (nullable = true)

# %%
dfIGDB_ExtGames.count()
# Out:
# 472539

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_ExtGames = (dfIGDB_ExtGames
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Definição do Enum 'category'

# %% [markdown]
# (Os Enums serão criados na camada context, e são fornecidos pelo IGDB na documentação da API. Exemplo utilizado disponível em: https://api-docs.igdb.com/?python#external-game)

# %%
schema = StructType([
    StructField("name", StringType(), True),
    StructField("value", IntegerType(), True)
])

data = [
    ("steam", 1),
    ("gog", 5),
    ("youtube", 10),
    ("microsoft", 11),
    ("apple", 13),
    ("twitch", 14),
    ("android", 15),
    ("amazon_asin", 20),
    ("amazon_luna", 22),
    ("amazon_adg", 23),
    ("epic_game_store", 26),
    ("oculus", 28),
    ("utomik", 29),
    ("itch_io", 30),
    ("xbox_marketplace", 31),
    ("kartridge", 32),
    ("playstation_store_us", 36),
    ("focus_entertainment", 37),
    ("xbox_game_pass_ultimate_cloud", 54),
    ("gamejolt", 55)
]

df_EnumCategory = spark.createDataFrame(data, schema=schema)

# %%
df_EnumCategory.show()
# Out:
# +--------------------+-----+
# |                name|value|
# +--------------------+-----+
# |               steam|    1|
# |                 gog|    5|
# |             youtube|   10|
# |           microsoft|   11|
# |               apple|   13|
# |              twitch|   14|
# |             android|   15|
# |         amazon_asin|   20|
# |         amazon_luna|   22|
# |          amazon_adg|   23|
# |     epic_game_store|   26|
# |              oculus|   28|
# |              utomik|   29|
# |             itch_io|   30|
# |    xbox_marketplace|   31|
# |           kartridge|   32|
# |playstation_store_us|   36|
# | focus_entertainment|   37|
# |xbox_game_pass_ul...|   54|
# |            gamejolt|   55|
# +--------------------+-----+

# %% [markdown]
# #### Exploração

# %%
# Número de Games por Plataforma (considerando multi-classificação)
dfGamesByExtPlatform = (dfIGDB_ExtGames
 .groupBy(fn.col("category"))
 .agg(fn.count("id").alias("Games"))
 .orderBy(fn.col("Games").desc())
)

total_titles = dfGamesByExtPlatform.agg(fn.sum("Games")).collect()[0][0]

(dfGamesByExtPlatform
 .join(df_EnumCategory, dfGamesByExtPlatform.category == df_EnumCategory.value, how="left")
 .withColumn("name", fn.when(fn.col("name").isNull(), "Unknown")
                             .otherwise(fn.col("name")))
 .withColumn("Percent", fn.round(((fn.col("Games") / total_titles) * 100), 2))
 .select(fn.col("name").alias("External Platforms"), fn.col("Games"), "Percent")
 .orderBy(fn.col("Games").desc())
).show(truncate=False)
# Out:
# +-----------------------------+------+-------+
# |External Platforms           |Games |Percent|
# +-----------------------------+------+-------+
# |twitch                       |199858|42.29  |
# |steam                        |102246|21.64  |
# |Unknown                      |73093 |15.47  |
# |amazon_asin                  |32255 |6.83   |
# |itch_io                      |11332 |2.4    |
# |microsoft                    |10995 |2.33   |
# |apple                        |9671  |2.05   |
# |playstation_store_us         |7734  |1.64   |
# |gog                          |6913  |1.46   |
# |epic_game_store              |6239  |1.32   |
# |android                      |3016  |0.64   |
# |utomik                       |2984  |0.63   |
# |xbox_marketplace             |1773  |0.38   |
# |youtube                      |1376  |0.29   |
# |kartridge                    |925   |0.2    |
# |gamejolt                     |674   |0.14   |
# |oculus                       |404   |0.09   |
# |xbox_game_pass_ultimate_cloud|388   |0.08   |
# |amazon_adg                   |317   |0.07   |
# |focus_entertainment          |183   |0.04   |
# +-----------------------------+------+-------+
# only showing top 20 rows

# %% [markdown]
# # Keywords

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'keywords'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_Keywords = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_Keywords.show(truncate=False)
# Out:
# +------------------------------------+----------+---+------------------+----------------+----------+------------------------------------------------+
# |checksum                            |created_at|id |name              |slug            |updated_at|url                                             |
# +------------------------------------+----------+---+------------------+----------------+----------+------------------------------------------------+
# |babab409-2c5d-9e05-1f1e-d2debfbb409e|1302739200|1  |modern warfare    |modern-warfare  |1323216000|https://www.igdb.com/categories/modern-warfare  |
# |fe5a303a-fe19-8678-0e94-6caf0af7c0dc|1302739200|3  |aliens            |aliens          |1323216000|https://www.igdb.com/categories/aliens          |
# |c3af99c2-270a-9df1-b06e-041b36f90857|1302739200|4  |pirates           |pirates         |1323216000|https://www.igdb.com/categories/pirates         |
# |19746d97-9387-b093-4f07-3f5a09796ce8|1302739200|5  |zombies           |zombies         |1403395200|https://www.igdb.com/categories/zombies         |
# |5f16f5ce-dae7-18e7-23af-58d98d2461b2|1302739200|6  |rail shooter      |rail-shooter    |1323216000|https://www.igdb.com/categories/rail-shooter    |
# |9bbe32be-9791-1873-de55-90546cb4f55e|1302825600|8  |cold war          |cold-war        |1323216000|https://www.igdb.com/categories/cold-war        |
# |a86497a9-a95e-b6c1-3613-3e3939b4acf1|1303430400|9  |western           |western         |1323216000|https://www.igdb.com/categories/western         |
# |6b94ad01-6096-2bce-d11c-e90df9d68e5e|1319932800|14 |super hero        |super-hero      |1365897600|https://www.igdb.com/categories/super-hero      |
# |bd8db255-9053-dd13-6932-fab3c6556765|1319932800|16 |ghosts            |ghosts          |1323216000|https://www.igdb.com/categories/ghosts          |
# |fae33a20-8b00-949e-4e99-3757aa386a38|1319979498|19 |world war ii - ww2|world-war-ii-ww2|1687493894|https://www.igdb.com/categories/world-war-ii-ww2|
# |9f9a3604-358a-c1a0-39b2-44b26b5cc292|1319932800|20 |baseball          |baseball        |1323216000|https://www.igdb.com/categories/baseball        |
# |3bc82bba-83e6-566b-c07d-c4f1a45c82df|1319932800|21 |helicopter        |helicopter      |1323216000|https://www.igdb.com/categories/helicopter      |
# |1c2024ae-c3e0-1b6b-b026-f2995bec92dc|1319932800|22 |assassin          |assassin        |1323216000|https://www.igdb.com/categories/assassin        |
# |1ae8cce9-b142-edc2-80f8-3bddae397a50|1319932800|23 |space simulation  |space-simulation|1323216000|https://www.igdb.com/categories/space-simulation|
# |3512a9c8-2b5b-2b2e-8fa1-88439589e710|1319932800|24 |space combat      |space-combat--2 |1323216000|https://www.igdb.com/categories/space-combat--2 |
# |8a24bad7-f765-c1f5-b160-921e869182d1|1319932800|25 |vehicular combat  |vehicular-combat|1323216000|https://www.igdb.com/categories/vehicular-combat|
# |b613768d-a5c8-3dac-b374-5da6c9922108|1320105600|26 |soccer            |soccer          |1323216000|https://www.igdb.com/categories/soccer          |
# |4fb659c0-542f-0780-3db4-e78be771c87b|1320105600|27 |football          |football        |1323216000|https://www.igdb.com/categories/football        |
# |e1f151e7-c59c-a8cb-a7f1-c23ecbb5ade6|1320192000|28 |rally             |rally           |1323216000|https://www.igdb.com/categories/rally           |
# |c2a4f5ed-bd9e-8b3f-bb0d-f242f11469be|1320313653|29 |world war i - ww1 |world-war-i-ww1 |1687493979|https://www.igdb.com/categories/world-war-i-ww1 |
# +------------------------------------+----------+---+------------------+----------------+----------+------------------------------------------------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_Keywords.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_Keywords.count()
# Out:
# 4295

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_Keywords = (dfIGDB_Keywords
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Languages

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'languages'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_languages = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_languages.show(30, truncate=False)
# Out:
# +------------------------------------+-------------------+---+------+---------------------+--------------------+-------------------+
# |checksum                            |created_at         |id |locale|name                 |native_name         |updated_at         |
# +------------------------------------+-------------------+---+------+---------------------+--------------------+-------------------+
# |e0963ddc-1e01-32e2-a959-d5ccda50410c|2022-10-03 13:27:19|1  |ar    |Arabic               |العربية             |2022-10-03 13:27:19|
# |ddcc7457-8939-17a3-9826-ef92d0d72371|2022-10-03 13:27:19|2  |zh-CN |Chinese (Simplified) |简体中文            |2022-10-03 13:27:19|
# |37988d2f-f5e5-663c-8cc5-5c27f463effe|2022-10-03 13:27:19|23 |sv-SE |Swedish              |Svenska             |2022-10-03 13:27:19|
# |3fa287a0-7ee0-f965-2282-93931077359c|2022-10-03 13:27:20|24 |tr-TR |Turkish              |Türkçe              |2022-10-03 13:27:20|
# |ec633fe7-383e-7831-7335-136cd446f771|2022-10-03 13:27:20|25 |th-TH |Thai                 |ไทย                 |2022-10-03 13:27:20|
# |b576a1df-38ab-7aa5-60b4-090c09be22e0|2022-10-03 13:27:20|26 |vi-VN |Vietnamese           |Tiếng Việt          |2022-10-03 13:27:20|
# |32a45eaa-c632-69d8-2318-c85812d0aae8|2022-10-18 09:36:33|27 |de-DE |German               |Deutsch             |2022-10-18 09:36:33|
# |598ca48d-ed49-704d-6501-ac1ea2358075|2022-10-18 09:37:51|28 |uk-UA |Ukrainian            |українська          |2022-10-18 09:37:51|
# +------------------------------------+-------------------+---+------+---------------------+--------------------+-------------------+

# %%
# Exibe o Schema do DataFrame
dfIGDB_languages.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- id: long (nullable = true)
#  |-- locale: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- native_name: string (nullable = true)
#  |-- updated_at: timestamp (nullable = true)

# %%
dfIGDB_languages.count()
# Out:
# 28

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_languages = (dfIGDB_languages
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Language Supports

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'language_supports'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_language_supports = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_language_supports.show(truncate=False)
# Out:
# +------------------------------------+-------------------+------+------+--------+---------------------+-------------------+
# |checksum                            |created_at         |game  |id    |language|language_support_type|updated_at         |
# +------------------------------------+-------------------+------+------+--------+---------------------+-------------------+
# |78f54dd1-aaf5-e3ed-7826-a238e500625e|2023-10-01 02:10:54|95210 |808764|21      |1                    |2023-10-03 07:43:14|
# |3b0e27ce-1c52-e936-f824-6611afe5bbe2|2023-10-01 02:10:54|95210 |808765|21      |2                    |2023-10-03 07:43:14|
# |f12263c0-240a-f85a-1a41-a2c78fc97587|2023-10-01 02:10:54|95210 |808766|22      |1                    |2023-10-03 07:43:14|
# |3fa9a31c-bb22-7b55-8e09-e7673b967fcc|2023-10-01 02:10:54|95210 |808767|22      |2                    |2023-10-03 07:43:14|
# |7abc16ca-3120-7f8e-fa87-1e38dff9d2bc|2023-10-01 02:11:56|268150|808768|27      |3                    |2023-10-01 15:44:37|
# |05aa46cb-126f-a589-c988-1d1ec0005bab|2023-10-01 02:11:56|268150|808769|9       |3                    |2023-10-01 15:44:37|
# |774fc49c-00ab-573b-acae-3fc758a1e73b|2023-10-01 02:11:56|268150|808770|4       |3                    |2023-10-01 15:44:37|
# |c97f2ce0-49e9-9764-ec5e-707c540df67d|2023-10-01 02:11:56|268150|808771|5       |3                    |2023-10-01 15:44:37|
# |488687ee-6814-7c1b-b11c-2f9483b29a4f|2023-10-01 02:11:56|268150|808772|6       |3                    |2023-10-01 15:44:37|
# |9a8560cc-68d4-9c1e-d3a8-a4e9b105265c|2023-10-01 02:11:56|268150|808773|11      |3                    |2023-10-01 15:44:37|
# |2036b72a-1461-b7b4-4728-574215a29755|2023-10-01 02:11:56|268150|808774|16      |3                    |2023-10-01 15:44:37|
# |c0b7ca06-b7a6-3123-86cb-0c139fb9db30|2023-10-01 02:11:56|268150|808775|17      |3                    |2023-10-01 15:44:37|
# |9947426f-e815-39d9-71bb-2009b2fbab63|2023-10-01 02:11:56|268150|808776|18      |3                    |2023-10-01 15:44:37|
# |2bba888c-00d0-e06d-e6db-ae8c7d3930ab|2023-10-01 02:11:56|268150|808777|19      |3                    |2023-10-01 15:44:37|
# |f8a138bb-3601-2622-c3ab-f0fd6ce908ae|2023-10-01 02:11:56|268150|808778|21      |3                    |2023-10-01 15:44:37|
# |aedb325e-0724-35b1-a676-e7f8b1278964|2023-10-01 02:11:56|268150|808779|22      |3                    |2023-10-01 15:44:37|
# |0fb05631-5c5e-9da7-01b7-ff292a7a53f1|2023-10-01 02:11:56|268150|808780|2       |3                    |2023-10-01 15:44:37|
# |ab5b011c-b0a9-b9e3-a3fc-dfddc3ea92fa|2023-10-01 02:11:56|268150|808781|23      |3                    |2023-10-01 15:44:37|
# |79123dbf-12f5-ba4b-d5bc-75c32a13dc2f|2023-10-01 02:11:56|268150|808782|3       |3                    |2023-10-01 15:44:37|
# |bbd20173-af6a-ff39-440b-935b50550fde|2023-10-01 02:53:11|269542|808783|7       |3                    |2023-10-02 21:21:15|
# +------------------------------------+-------------------+------+------+--------+---------------------+-------------------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_language_supports.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- game: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- language: long (nullable = true)
#  |-- language_support_type: long (nullable = true)
#  |-- updated_at: timestamp (nullable = true)

# %%
dfIGDB_language_supports.count()
# Out:
# 773558

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_language_supports = (dfIGDB_language_supports
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Language Support Types

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'language_support_types'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_language_support_types = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_language_support_types.show(truncate=False)
# Out:
# +------------------------------------+-------------------+---+---------+-------------------+
# |checksum                            |created_at         |id |name     |updated_at         |
# +------------------------------------+-------------------+---+---------+-------------------+
# |17300b0f-8e60-5cf7-2b2d-6797e4ccb813|2022-10-03 13:27:19|1  |Audio    |2022-10-03 13:27:19|
# |8de2491d-254c-c271-655c-07a9153883dc|2022-10-03 13:27:19|2  |Subtitles|2022-10-03 13:27:19|
# |f7b81411-acba-02d2-9131-e8a4ebef763d|2022-10-03 13:27:19|3  |Interface|2022-10-03 13:27:19|
# +------------------------------------+-------------------+---+---------+-------------------+

# %%
# Exibe o Schema do DataFrame
dfIGDB_language_support_types.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- game: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- language: long (nullable = true)
#  |-- language_support_type: long (nullable = true)
#  |-- updated_at: timestamp (nullable = true)

# %%
dfIGDB_language_support_types.count()
# Out:
# 773558

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_language_support_types = (dfIGDB_language_support_types
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Themes

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'themes'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_themes = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_themes.show(30, truncate=False)
# Out:
# +------------------------------------+-------------------+---+----------------------------------------------+-----------------------------------------+-------------------+---------------------------------------------------------------------+
# |checksum                            |created_at         |id |name                                          |slug                                     |updated_at         |url                                                                  |
# +------------------------------------+-------------------+---+----------------------------------------------+-----------------------------------------+-------------------+---------------------------------------------------------------------+
# |c177e0ff-f29a-2a2e-fce5-f945258ceb59|2011-11-29 00:00:00|1  |Action                                        |action                                   |2011-12-07 00:00:00|https://www.igdb.com/themes/action                                   |
# |454bdc25-3dbf-5648-1e11-fc67ffc893aa|2011-11-29 00:00:00|17 |Fantasy                                       |fantasy                                  |2011-12-07 00:00:00|https://www.igdb.com/themes/fantasy                                  |
# |fffad274-fee4-e195-eb78-72b2a35d643e|2011-11-29 00:00:00|18 |Science fiction                               |science-fiction                          |2011-12-07 00:00:00|https://www.igdb.com/themes/science-fiction                          |
# |28762ccf-724f-56cf-3784-dbf16dfcf174|2011-11-29 00:00:00|19 |Horror                                        |horror                                   |2011-12-07 00:00:00|https://www.igdb.com/themes/horror                                   |
# |4ebeaa43-4165-5d23-142a-9bb2a26c7024|2011-11-29 00:00:00|20 |Thriller                                      |thriller                                 |2011-12-07 00:00:00|https://www.igdb.com/themes/thriller                                 |
# |01d5251e-746d-d9b6-6a47-99e8e9fda8ff|2011-11-29 00:00:00|21 |Survival                                      |survival                                 |2011-12-07 00:00:00|https://www.igdb.com/themes/survival                                 |
# |1256e1bd-db05-276a-16ad-9704f7a56dcc|2011-11-29 00:00:00|22 |Historical                                    |historical                               |2011-12-07 00:00:00|https://www.igdb.com/themes/historical                               |
# |6c0cc20c-b7fc-0007-8ae0-4cc91301e9f1|2011-11-29 00:00:00|23 |Stealth                                       |stealth                                  |2011-12-07 00:00:00|https://www.igdb.com/themes/stealth                                  |
# |2d128835-a3c1-7979-d561-005e651ada8e|2011-11-29 00:00:00|27 |Comedy                                        |comedy                                   |2011-12-07 00:00:00|https://www.igdb.com/themes/comedy                                   |
# |b088a483-b1e9-685b-dbfb-4e37b58ef69d|2011-11-29 00:00:00|28 |Business                                      |business                                 |2011-12-07 00:00:00|https://www.igdb.com/themes/business                                 |
# |38bf13b9-353e-d24e-b5fa-3d471c9e1e84|2011-12-11 00:00:00|31 |Drama                                         |drama                                    |2011-12-11 00:00:00|https://www.igdb.com/themes/drama                                    |
# |67e7350e-501b-9608-a68f-97f698582483|2011-12-11 00:00:00|32 |Non-fiction                                   |non-fiction                              |2011-12-11 00:00:00|https://www.igdb.com/themes/non-fiction                              |
# |379eaafa-9fa2-9847-a6e2-b04b82687038|2012-01-14 00:00:00|33 |Sandbox                                       |sandbox                                  |2012-01-14 00:00:00|https://www.igdb.com/themes/sandbox                                  |
# |49695f76-0b6a-36bc-1a4a-db0eddf4beec|2012-01-17 00:00:00|34 |Educational                                   |educational                              |2012-01-17 00:00:00|https://www.igdb.com/themes/educational                              |
# |0d518e1e-a2be-1b31-40ab-6bd28ec850f1|2012-01-17 00:00:00|35 |Kids                                          |kids                                     |2012-01-17 00:00:00|https://www.igdb.com/themes/kids                                     |
# |7a78c421-ffaa-d859-d1ea-0b0974e3abd0|2012-08-20 00:00:00|38 |Open world                                    |open-world                               |2012-08-20 00:00:00|https://www.igdb.com/themes/open-world                               |
# |384162d9-4646-885c-1fae-a18b0147dfa6|2012-08-20 00:00:00|39 |Warfare                                       |warfare                                  |2012-08-20 00:00:00|https://www.igdb.com/themes/warfare                                  |
# |d28d8158-faa6-eb02-2510-4750764bdd6e|2012-12-30 00:00:00|40 |Party                                         |party                                    |2012-12-30 00:00:00|https://www.igdb.com/themes/party                                    |
# |62e181d9-60fe-30c7-c884-e4341d2d3bd5|2013-01-02 00:00:00|41 |4X (explore, expand, exploit, and exterminate)|4x-explore-expand-exploit-and-exterminate|2013-01-02 00:00:00|https://www.igdb.com/themes/4x-explore-expand-exploit-and-exterminate|
# |a28e9969-76b8-5c50-1c3a-7db3b711aba1|2016-05-20 00:00:00|42 |Erotic                                        |erotic                                   |2016-05-20 00:00:00|https://www.igdb.com/themes/erotic                                   |
# |e5276bc0-d8aa-6d85-6605-3c009ebdffa1|2016-06-06 00:00:00|43 |Mystery                                       |mystery                                  |2016-06-06 00:00:00|https://www.igdb.com/themes/mystery                                  |
# |a756089a-291f-c3bc-e589-62afe1fcacc1|2020-05-07 00:00:00|44 |Romance                                       |romance                                  |2020-05-07 00:00:00|https://www.igdb.com/themes/romance                                  |
# +------------------------------------+-------------------+---+----------------------------------------------+-----------------------------------------+-------------------+---------------------------------------------------------------------+

# %%
# Exibe o Schema do DataFrame
dfIGDB_themes.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_themes.count()
# Out:
# 22

# %% [markdown]
# #### Converte os campos de data para Unix Timestamp

# %%
dfIGDB_themes = (dfIGDB_themes
                .withColumn("created_at", fn.to_timestamp(fn.from_unixtime("created_at")))
                .withColumn("updated_at", fn.to_timestamp(fn.from_unixtime("updated_at")))
               )

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Multiplayer Modes

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'multiplayer_modes'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_multiplayer_modes = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_multiplayer_modes.show(truncate=False)
# Out:
# +------------+------------------------------------+------+-----+---+-------+-----------+--------------+----------+----------+-------------+---------+--------+-----------+
# |campaigncoop|checksum                            |dropin|game |id |lancoop|offlinecoop|offlinecoopmax|offlinemax|onlinecoop|onlinecoopmax|onlinemax|platform|splitscreen|
# +------------+------------------------------------+------+-----+---+-------+-----------+--------------+----------+----------+-------------+---------+--------+-----------+
# |false       |03778a0f-3bb3-a0f0-c835-e3bbef146b4d|false |11120|5  |false  |false      |null          |null      |false     |null         |2        |6       |false      |
# |false       |dc1f6640-eee4-7ed0-740b-4afb23667bcf|false |11120|6  |false  |false      |null          |null      |false     |null         |2        |14      |false      |
# |false       |a41bcf9c-976d-8690-629f-4c2737f65bf1|false |46076|7  |false  |false      |null          |30        |false     |null         |null     |6       |false      |
# |false       |d98cddc4-1777-83da-8401-4fa6b97e73a2|false |46077|8  |false  |false      |null          |null      |false     |null         |null     |6       |false      |
# |false       |7530f8ea-d619-5243-bc7f-f3adb1ab3918|false |46659|12 |false  |false      |6             |null      |false     |null         |null     |null    |false      |
# |false       |2d4ac89b-78d0-2917-8151-291181c40946|false |45111|13 |false  |false      |null          |2         |false     |null         |2        |48      |false      |
# |false       |1808a035-828a-071f-53e9-e8a579ba3008|false |45515|20 |false  |false      |null          |2         |false     |null         |null     |7       |true       |
# |false       |0aa16851-2b17-7767-b562-2b29f2e01a9a|true  |48336|21 |false  |false      |null          |null      |false     |null         |12       |34      |false      |
# |false       |4e1d0c7d-c611-c433-3e77-1707eef1912b|true  |48336|22 |false  |false      |null          |null      |false     |null         |12       |39      |false      |
# |false       |448fd7d1-44a0-1c95-3223-75295544fa21|false |48675|23 |false  |false      |0             |0         |true      |2            |2        |34      |false      |
# |false       |0ce31605-d400-a609-4e08-35044fad0ea6|false |48675|24 |false  |false      |0             |0         |true      |2            |2        |39      |false      |
# |false       |6ba886f4-3c39-fe8f-b342-96b83ea9c816|false |49118|25 |false  |false      |null          |null      |false     |null         |null     |59      |false      |
# |false       |daaf45e8-3329-0c8b-717d-7fb03510249d|false |14431|28 |false  |false      |null          |null      |false     |null         |null     |13      |true       |
# |false       |2f30899d-907a-d928-424b-3d764ddd15b4|false |51551|31 |false  |false      |null          |null      |false     |null         |null     |34      |false      |
# |false       |8e43384d-b731-1948-d3b0-c48d63a6e70a|false |51693|34 |false  |false      |null          |null      |false     |null         |null     |49      |false      |
# |false       |e6493450-2b9e-1db1-c79f-883a2f5ed4a4|false |51693|35 |false  |false      |null          |null      |false     |null         |null     |48      |false      |
# |false       |89e44830-cff6-973c-5804-53c336a95357|true  |26742|36 |false  |false      |null          |null      |true      |null         |null     |82      |false      |
# |true        |167fbc96-0d76-a412-9f47-4f1d9952df96|false |27666|39 |false  |true       |2             |null      |false     |null         |null     |6       |false      |
# |true        |d69bc18d-6d4c-92be-5d31-96af4ee501b8|false |27666|40 |false  |true       |2             |null      |false     |null         |null     |12      |false      |
# |true        |2cf7517d-6beb-21eb-f623-2a29b26d3ee0|false |27666|41 |false  |true       |2             |null      |false     |null         |null     |48      |false      |
# +------------+------------------------------------+------+-----+---+-------+-----------+--------------+----------+----------+-------------+---------+--------+-----------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_multiplayer_modes.printSchema()
# Out:
# root
#  |-- campaigncoop: boolean (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- dropin: boolean (nullable = true)
#  |-- game: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- lancoop: boolean (nullable = true)
#  |-- offlinecoop: boolean (nullable = true)
#  |-- offlinecoopmax: long (nullable = true)
#  |-- offlinemax: long (nullable = true)
#  |-- onlinecoop: boolean (nullable = true)
#  |-- onlinecoopmax: long (nullable = true)
#  |-- onlinemax: long (nullable = true)
#  |-- platform: long (nullable = true)
#  |-- splitscreen: boolean (nullable = true)

# %%
dfIGDB_multiplayer_modes.count()
# Out:
# 14131

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Franchises

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'franchises'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_franchises = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_franchises.show(truncate=False)
# Out:
# +------------------------------------+-------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---+---------------------+---------------------+----------+-----------------------------------------------------+
# |checksum                            |created_at   |games                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |id |name                 |slug                 |updated_at|url                                                  |
# +------------------------------------+-------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---+---------------------+---------------------+----------+-----------------------------------------------------+
# |bc368462-79d8-0eea-93e9-83036ca4e219|1301132282000|[114, 116, 118, 137, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 166, 167, 168, 169, 170, 171, 172, 173, 174, 190, 206, 210, 475, 476, 1386, 2113, 2681, 2682, 4180, 4181, 4182, 4674, 5194, 5599, 5706, 6159, 6160, 6606, 6607, 6608, 6609, 6844, 8147, 8148, 8560, 8799, 10203, 10204, 10205, 11083, 11178, 11289, 12594, 12732, 12842, 12858, 13483, 14401, 17030, 17474, 17475, 17476, 18044, 18046, 18161, 18950, 18951, 19272, 19419, 19429, 19577, 19637, 19869, 20004, 20005, 20031, 20470, 20937, 21335, 21739, 21743, 22626, 22655, 22656, 22657, 22658, 22659, 23063, 23116, 23293, 23365, 23976, 25304, 26201, 26401, 30979, 34982, 35596, 35968, 39245, 39351, 39751, 39822, 44463, 45334, 45379, 46892, 48939, 51486, 52877, 52879, 53271, 54401, 54649, 56979, 61864, 62510, 62669, 63429, 64562, 65161, 66424, 67944, 70221, 72396, 74701, 74866, 74895, 74896, 74901, 74963, 74964, 74979, 75085, 75086, 75087, 75088, 75089, 75120, 75559, 75560, 75561, 75562, 75564, 75565, 75566, 76411, 76721, 76722, 76730, 76886, 76946, 77212, 78357, 86260, 91751, 92035, 93832, 95480, 97498, 102600, 110419, 117405, 119305, 122557, 122633, 125987, 126168, 134706, 134955, 134957, 136076, 138105, 138124, 138161, 138163, 138164, 138165, 138291, 143328, 143611, 146363, 150053, 150523, 166008, 166484, 167612, 167641, 168392, 168665, 185865, 185866, 193296, 194935, 194937, 194948, 197926, 198108, 198906, 198907, 198908, 198909, 198910, 198911, 198912, 198913, 198914, 198915, 198916, 198917, 198918, 198919, 198920, 198921, 198922, 198925, 199005, 199015, 199016, 199822, 200677, 201129, 201137, 201138, 201139, 201140, 201156, 202715
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |23 |Alien                |alien                |1698081859|https://www.igdb.com/franchises/alien                |
# |8c8353a1-5e98-c44d-12af-9cee4ffd15ca|1339334809730|null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |24 |Mario Bros.          |mario-bros           |1661253408|https://www.igdb.com/franchises/mario-bros           |
# +------------------------------------+-------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---+---------------------+---------------------+----------+-----------------------------------------------------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_franchises.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- created_at: long (nullable = true)
#  |-- games: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_franchises.count()
# Out:
# 1855

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Collections

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'collections'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_collections = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_collections.show(truncate=False)
# Out:
# +------------------------------------+----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---+--------------------------------------+-------------------------------------+----------+----------------------------------------------------------------------+
# |checksum                            |created_at|games                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |id |name                                  |slug                                 |updated_at|url                                                                   |
# +------------------------------------+----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---+--------------------------------------+-------------------------------------+----------+----------------------------------------------------------------------+
# |9d369990-e23d-4458-5213-6d93ec1315c5|1298843586|[10047, 23038, 96406, 117315, 152660, 214790]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |1  |Bioshock                              |bioshock                             |1697734587|https://www.igdb.com/collections/bioshock                             |
# |428a3413-fb06-1fff-8861-192e8e86b0bd|1298844139|[1, 2, 3, 4, 9227, 53797, 117274, 159252]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |2  |Thief                                 |thief                                |1697461314|https://www.igdb.com/collections/thief                                |
# |4aa8285e-3fc3-1fce-15af-b37a4bde0c99|1298852984|[13, 14, 15, 16, 17, 7412, 9630, 10299, 10300, 10301, 10302, 10303, 10304, 10305, 10306, 10307, 11119, 12508, 12509, 18029, 18030, 18031, 19532, 19533, 19534, 21584, 21590, 21892, 25532, 25878, 27922, 43022, 45127, 45128, 45129, 45130, 54612, 72379, 72381, 77192, 79217, 89845, 103020, 115713, 131851, 132140, 132141, 142745, 143196, 187871, 217785, 229978, 232689, 267307]                                                                                                                                                                                                                                                                                                                                                                                                                                        |3  |Fallout                               |fallout                              |1698451017|https://www.igdb.com/collections/fallout                              |
# |8a82100b-4315-fbe6-be69-a921ee8062b4|1298893828|[44604, 44613, 44668]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |4  |Dead Space                            |dead-space                           |1697102193|https://www.igdb.com/collections/dead-space                           |
# |0188612f-0ce2-f26e-b0a4-e9ebcc3f865d|1298975806|[60, 61, 62, 63, 64, 65, 66, 195517]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |5  |Monkey Island                         |monkey-island                        |1697420073|https://www.igdb.com/collections/monkey-island                        |
array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- slug: string (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_collections.count()
# Out:
# 7744

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Game Engines

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'game_engines'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_game_engines = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_game_engines.show(truncate=False)
# Out:
# +------------------------------------+----------+----------+---+----+----------------+----------------------------------------------------+----------------+----------+--------------------------------------------------+
# |checksum                            |companies |created_at|id |logo|name            |platforms                                           |slug            |updated_at|url                                               |
# +------------------------------------+----------+----------+---+----+----------------+----------------------------------------------------+----------------+----------+--------------------------------------------------+
# |0451dbf6-af33-bd30-3e67-4d841bf540ce|[94]      |1399505504|2  |0   |Frostbite       |[6, 9, 12, 48, 49]                                  |frostbite       |1689275304|https://www.igdb.com/game_engines/frostbite       |
# |819a0785-9dee-dcbb-8666-f2db43f0e26e|[56]      |1399579055|3  |0   |Source          |[3, 6, 9, 11, 12, 14, 34]                           |source          |1698308926|https://www.igdb.com/game_engines/source          |
# |b8c84b9b-02fc-18f9-95da-6815b067aae2|[56]      |1399579593|4  |0   |GoldSrc         |[3, 6, 8, 11, 14, 23]                               |goldsrc         |1694399423|https://www.igdb.com/game_engines/goldsrc         |
# |6e4516bc-7c81-443c-e019-fed9950bb4eb|null      |1399507200|5  |null|NeL             |null                                                |nel             |1399593600|https://www.igdb.com/game_engines/nel             |
# |bcc32033-8ea5-c708-3ad7-bbb6418a48dd|[17463]   |1399589201|6  |0   |Unreal Engine   |[3, 5, 6, 8, 9, 11, 12, 14, 39]                     |unreal-engine   |1698396247|https://www.igdb.com/game_engines/unreal-engine   |
# |100ed1c7-0185-2242-aaae-6d043cb468a8|[38]      |1399589468|7  |null|Scimitar        |[6, 9, 12]                                          |scimitar        |1688946512|https://www.igdb.com/game_engines/scimitar        |
# |3b9e3c46-4728-549e-3e2e-d34859a0f5d1|null      |1399589468|8  |0   |Havok           |null                                                |havok           |1685532465|https://www.igdb.com/game_engines/havok           |
# |5d94ad0d-0daf-108a-ca74-6da5a343e46c|[38]      |1399507200|9  |null|Anvil           |[6, 9, 12, 41, 46]                                  |anvil           |1610582400|https://www.igdb.com/game_engines/anvil           |
# |b915e58c-1927-eff6-946f-85432205e4bb|[38]      |1399589737|10 |0   |AnvilNext       |[6, 9, 12, 41, 46, 48, 49]                          |anvilnext       |1688949658|https://www.igdb.com/game_engines/anvilnext       |
# |52c4d3d4-0f69-9ef1-5a6c-f1dd4357c0ae|null      |1399826402|12 |0   |Telltale Tool   |null                                                |telltale-tool   |1661417811|https://www.igdb.com/game_engines/telltale-tool   |
# |c8399a5d-1a5b-b803-29f4-bf4341404f79|[3067]    |1399839244|13 |0   |Unity           |[3, 5, 6, 9, 12, 14, 34, 39, 41, 46, 48, 49, 74, 82]|unity           |1698440696|https://www.igdb.com/game_engines/unity           |
# |825168d6-a73b-13fb-2a9d-75ccb0f4ec51|null      |1399975818|14 |0   |MT Framework    |null                                                |mt-framework    |1664309575|https://www.igdb.com/game_engines/mt-framework    |
# |dce6e214-e55a-5549-8f25-85323f5ae4b7|null      |1400976000|16 |null|Disrupt         |null                                                |disrupt         |1575158400|https://www.igdb.com/game_engines/disrupt         |
# |1c31bdc8-b1fd-e29f-b0a2-29cd2e47b605|null      |1401028970|17 |null|Havok Physics   |null                                                |havok-physics   |1695052563|https://www.igdb.com/game_engines/havok-physics   |
# |ae00c634-e2e6-ffab-d9a8-0cf352601b12|[314]     |1401212950|18 |33  |4A Engine       |[3, 6, 9, 12, 14, 48, 49]                           |4a-engine       |1624005260|https://www.igdb.com/game_engines/4a-engine       |
# |d5965f1e-5193-e394-f77b-e1e30a57bbe6|[104, 537]|1401541429|19 |0   |Snowdrop        |[6, 48, 49, 130, 170]                               |snowdrop        |1686593354|https://www.igdb.com/game_engines/snowdrop        |
# |0318f539-1091-8409-8941-dcd34f69c095|null      |1402260498|20 |null|Doom engine     |null                                                |doom-engine     |1693473017|https://www.igdb.com/game_engines/doom-engine     |
# |f4ee5f76-c1dc-43b1-338b-42b772ff0322|[5851]    |1402403206|21 |null|TheEngine       |[6, 14]                                             |theengine       |1671018439|https://www.igdb.com/game_engines/theengine       |
# |b704272f-e49c-bbcf-6f47-0af77e29dcd2|null      |1402435973|22 |0   |UbiArt Framework|null                                                |ubiart-framework|1673630175|https://www.igdb.com/game_engines/ubiart-framework|
# |0f5cdff7-ae38-7014-35a2-469c7968dc4e|null      |1402531200|23 |null|Serious Engine 4|null                                                |serious-engine-4|1452211200|https://www.igdb.com/game_engines/serious-engine-4|
# +------------------------------------+----------+----------+---+----+----------------+----------------------------------------------------+----------------+----------+--------------------------------------------------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_game_engines.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- companies: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- created_at: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- logo: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- platforms: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- slug: string (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_game_engines.count()
# Out:
# 1201

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Game Engine Logos

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'game_engine_logos'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_game_engine_logos = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_game_engine_logos.show(truncate=False)
# Out:
# +-------------+--------+------------------------------------+------+---+--------------------+--------------------------------------------------------------------+-----+
# |alpha_channel|animated|checksum                            |height|id |image_id            |url                                                                 |width|
# +-------------+--------+------------------------------------+------+---+--------------------+--------------------------------------------------------------------+-----+
# |null         |null    |4a343234-49b9-be6f-56e3-5b37c1569979|256   |7  |yet7ledalhypkqxpdcfz|//images.igdb.com/igdb/image/upload/t_thumb/yet7ledalhypkqxpdcfz.jpg|256  |
# |null         |null    |8d1d8a48-280d-452e-8192-4ab34fdea659|204   |9  |rk2pcdi9skhph6e5ysby|//images.igdb.com/igdb/image/upload/t_thumb/rk2pcdi9skhph6e5ysby.jpg|660  |
# |null         |null    |8427de38-dd2a-1240-72b4-b6cb96c1c8e3|343   |11 |qqvzsxjdjr6qk310gzne|//images.igdb.com/igdb/image/upload/t_thumb/qqvzsxjdjr6qk310gzne.jpg|288  |
# |null         |null    |5f2de195-065c-711f-fb10-f341ae970738|142   |28 |hskokmjlchb2lgz4tblt|//images.igdb.com/igdb/image/upload/t_thumb/hskokmjlchb2lgz4tblt.jpg|400  |
# |null         |null    |cbdc408f-6e4f-cdc2-10d2-1986bb34f2b1|100   |29 |bt3ccfyvr5flu1zccktc|//images.igdb.com/igdb/image/upload/t_thumb/bt3ccfyvr5flu1zccktc.jpg|250  |
# |null         |null    |f030b1cf-d445-e3a2-42b3-728957ea9b1d|128   |30 |prfbgzvm7gjws62e4qbq|//images.igdb.com/igdb/image/upload/t_thumb/prfbgzvm7gjws62e4qbq.jpg|163  |
# +-------------+--------+------------------------------------+------+---+--------------------+--------------------------------------------------------------------+-----+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_game_engine_logos.printSchema()
# Out:
# root
#  |-- alpha_channel: boolean (nullable = true)
#  |-- animated: boolean (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- height: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- image_id: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- width: long (nullable = true)

# %%
dfIGDB_game_engine_logos.count()
# Out:
# 169

# %% [markdown]
# # Companies

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'companies'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_companies = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_companies.show()
# Out:
# +-----------+--------------------+------------------+--------------------+-------+----------+--------------------+--------------------+---+----+--------------------+------+--------------------+--------------------+----------+-------------------+----------+--------------------+--------+
# |change_date|change_date_category|changed_company_id|            checksum|country|created_at|         description|           developed| id|logo|                name|parent|           published|                slug|start_date|start_date_category|updated_at|                 url|websites|
# +-----------+--------------------+------------------+--------------------+-------+----------+--------------------+--------------------+---+----+--------------------+------+--------------------+--------------------+----------+-------------------+----------+--------------------+--------+
# |       null|                   7|                 5|00a2eed3-db13-e9a...|    840|1297810753|Electronic Arts i...|[1621, 2166, 3011...|  1|5620|     Electronic Arts|  null|[10, 11, 22, 35, ...|     electronic-arts| 391392000|                  0|1699383317|https://www.igdb....|  [1076]|
# |       null|                   7|              null|0eb91473-4bcb-d01...|    124|1297810806|BioWare is a Cana...|[5, 6, 10, 73, 74...|  2|6325|             BioWare|     1|[13784, 22963, 22...|             bioware| 791596800|                  1|1697571700|https://www.igdb....|  [1057]|
# |  959126400|                   0|              null|9221bb20-13be-10e...|    840|1297817573|                null|[1, 2, 22, 23, 70...|  3|  13|Looking Glass Stu...|  null|   [70, 3352, 62333]|looking-glass-stu...| 638841600|                  3|1698004107|https://www.igdb....|    null|
# | 1257724800|                   0|              4940|cad3c62b-d6c1-b01...|    826|1297817598|Now called Square...|[4223, 5259, 5770...|  4| 357|   Eidos Interactive|    26|[1, 2, 3, 41, 42,...|   eidos-interactive| 833500800|                  0|1699319788|https://www.igdb....|   [358]|
# |       null|                   7|              null|c5e8abad-1662-1f8...|    840|1297817647|Founded in 1983, ...|[253, 775, 3461, ...|  5| 955|Interplay Enterta...|  null|[5, 6, 13, 14, 34...|interplay-enterta...| 441676800|                  2|1699319827|https://www.igdb....|  [1036]|
# | 1461888000|                   0|              null|095a8eb5-22ed-278...|    826|1297817708|Lionhead Studios ...|[308, 504, 522, 6...|  6|6401|    Lionhead Studios|  null|                null|    lionhead-studios| 851990400|                  2|1698840786|https://www.igdb....|   [360]|
# | 1392681600|                   0|              null|a2a3a4c1-6de8-cd1...|    840|1299323621|Irrational Games ...|[22, 316, 317, 53...| 21|6538|    Irrational Games|   139|                null|    irrational-games| 883526400|                  2|1697619905|https://www.igdb....|    [61]|
# +-----------+--------------------+------------------+--------------------+-------+----------+--------------------+--------------------+---+----+--------------------+------+--------------------+--------------------+----------+-------------------+----------+--------------------+--------+
# only showing top 20 rows

# %%
dfIGDB_companies.describe().show()
# Out:
# +-------+--------------------+--------------------+------------------+--------------------+-----------------+--------------------+--------------------+------------------+-----------------+--------------------+------------------+--------------------+--------------------+-------------------+--------------------+--------------------+
# |summary|         change_date|change_date_category|changed_company_id|            checksum|          country|          created_at|         description|                id|             logo|                name|            parent|                slug|          start_date|start_date_category|          updated_at|                 url|
# +-------+--------------------+--------------------+------------------+--------------------+-----------------+--------------------+--------------------+------------------+-----------------+--------------------+------------------+--------------------+--------------------+-------------------+--------------------+--------------------+
# |  count|                 915|               48401|               411|               48401|             9301|               48401|                7223|             48401|             7843|               48401|              1200|               48401|                5219|              48401|               48401|               48401|
# |   mean| 2.975802019672131E8|   6.701865663932564| 9677.549878345499|                null|516.0865498333512|1.5631233461693146E9|                null|24994.615131918763|5100.886778018616|            Infinity|10215.681666666667|            Infinity| 6.916187891933321E8|  6.179211173322865|1.5969737324180698E9|                null|
# | stddev|7.4870029438906555E9|  1.3793782400572852|13306.074133755377|                null|282.3294882361309| 9.193461542210433E7|                null|14460.353313400137|3005.077090653008|                 NaN| 13194.81311505704|                 NaN|5.9345294886326885E9|  2.115788358446953| 8.002524811061858E7|                null|
# |    min|        -62135683200|                   0|                 0|0000a32b-13a6-448...|                4|          1297810753|"100 Stones Inter...|                 1|                6|"LUXOR" Renderer ...|                 1|                    |        -62135683200|                  0|          1323289194|https://www.igdb....|
# |    max|          1696896000|                   7|             49811|ffffcab6-5496-de0...|              882|          1699740217|⭐ Shoot for the s...|             50879|            10489|            龍成網絡|             50699|zzyzx-rd-game-stu...|          1703980800|                  7|          1699740217|https://www.igdb....|
# +-------+--------------------+--------------------+------------------+--------------------+-----------------+--------------------+--------------------+------------------+-----------------+--------------------+------------------+--------------------+--------------------+-------------------+--------------------+--------------------+

# %%
(
    dfIGDB_companies
    .select("change_date", "changed_company_id", "id", "created_at", "name", "updated_at")
    .where(fn.col("changed_company_id").isNotNull())
    .orderBy("changed_company_id", ascending=True)
).show(50, False)
# Out:
# +-----------+------------------+-----+----------+-------------------------------------+----------+
# |change_date|changed_company_id|id   |created_at|name                                 |updated_at|
# +-----------+------------------+-----+----------+-------------------------------------+----------+
# |1230681600 |0                 |2846 |1398917131|Mad Doc Software                     |1697735451|
# |788832000  |1                 |10337|1468231604|Dro Soft                             |1698053280|
# |null       |5                 |1    |1297810753|Electronic Arts                      |1699383317|
# |915062400  |5                 |903  |1357165107|Interplay Productions                |1698308445|
# |null       |5                 |2621 |1397072659|Intermetrics Entertainment Software  |1397072686|
# |null       |6                 |410  |1317629025|Big Blue Box                         |1698840786|
# |957916800  |213               |205  |1302006203|GT Interactive Software              |1698786588|
# +-----------+------------------+-----+----------+-------------------------------------+----------+
# only showing top 50 rows

# %%
(
    dfIGDB_companies
    .select("change_date", "changed_company_id", "id", "created_at", "name", "updated_at")
    .where((fn.col("changed_company_id") == 190) | (fn.col("id") == 190) | (fn.col("changed_company_id") == 7647)| (fn.col("id") == 7647))
    .orderBy("name", ascending=True)
).show(truncate=False)
# Out:
# +-----------+------------------+-----+----------+----------------------+----------+
# |change_date|changed_company_id|id   |created_at|name                  |updated_at|
# +-----------+------------------+-----+----------+----------------------+----------+
# |457488000  |190               |82   |1300206663|Atari                 |1699373825|
# |889747200  |7647              |190  |1301988748|Atari Corporation     |1698850846|
# |null       |null              |7647 |1449925673|Atari Interactive     |1698786556|
# |null       |190               |2406 |1392893070|Atari, Inc.           |1698879444|
# |1051747200 |7647              |29492|1605029691|Infogrames Interactive|1698758031|
# +-----------+------------------+-----+----------+----------------------+----------+

# %%
(
    dfIGDB_Games
    .select("id", "name", "involved_companies")
    .filter((fn.array_contains("involved_companies", 190)) | 
            (fn.array_contains("involved_companies", 82)) |
            (fn.array_contains("involved_companies", 2406)) |
            (fn.array_contains("involved_companies", 29492)) |
            (fn.array_contains("involved_companies", 7647)))
).show(20, False)
# Out:
# +-----+-------------+-----------------------------+
# |id   |name         |involved_companies           |
# +-----+-------------+-----------------------------+
# |219  |MDK          |[186, 189, 190, 43831, 43832]|
# |15495|Jones on Fire|[29492, 133567, 133568]      |
# +-----+-------------+-----------------------------+

# %%
# Exibe o Schema do DataFrame
dfIGDB_companies.printSchema()
# Out:
# root
#  |-- change_date: long (nullable = true)
#  |-- change_date_category: long (nullable = true)
#  |-- changed_company_id: long (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- country: long (nullable = true)
#  |-- created_at: long (nullable = true)
#  |-- description: string (nullable = true)
#  |-- developed: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- id: long (nullable = true)
#  |-- logo: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- parent: long (nullable = true)
#  |-- published: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- slug: string (nullable = true)
#  |-- start_date: long (nullable = true)
#  |-- start_date_category: long (nullable = true)
#  |-- updated_at: long (nullable = true)
#  |-- url: string (nullable = true)
#  |-- websites: array (nullable = true)
#  |    |-- element: long (containsNull = true)

# %%
dfIGDB_companies.count()
# Out:
# 48401

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Involved Companies

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'involved_companies'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_involved_companies = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_involved_companies.show(truncate=False)
# Out:
# +------------------------------------+-------+----------+---------+------+------+-------+---------+----------+----------+
# |checksum                            |company|created_at|developer|game  |id    |porting|publisher|supporting|updated_at|
# +------------------------------------+-------+----------+---------+------+------+-------+---------+----------+----------+
# |98678387-4f43-7c38-4fba-e1b52d04e07c|129    |1664981310|true     |4615  |189796|false  |true     |false     |1664982753|
# |9af87b13-5fad-df94-9f0a-08691a15316d|129    |1664981375|true     |213191|189797|false  |true     |false     |1665005743|
# |74ea3067-9bb9-124d-a276-b3891f62fa96|1287   |1664981540|true     |214458|189800|false  |false    |false     |1665005760|
# |8f72268b-727f-16a8-4883-28ec39b886bc|1809   |1664981540|true     |214458|189801|false  |false    |false     |1665005760|
# |13ba02ec-801e-ef46-5086-df6ff40b0fc9|70     |1664981540|false    |214458|189802|false  |true     |false     |1665005760|
# |ad8ea895-29be-687b-b46a-fcd6e848d619|1774   |1664981675|true     |3400  |189803|false  |false    |false     |1665005770|
# |77244c48-f04d-f034-d304-1b6086dfe569|762    |1664981675|true     |3400  |189804|false  |false    |false     |1665005770|
# |5cc1d42a-1563-6bb7-ee05-a10424a7ce87|70     |1664981676|false    |3400  |189805|false  |true     |false     |1665005770|
# |67885cee-d6fe-3e9a-8af2-3a7b0bf78d44|37     |1664981759|true     |1716  |189806|false  |true     |false     |1665005775|
# |7bc84737-b3b5-483d-e943-b38997597245|70     |1664981809|false    |1101  |189807|false  |true     |false     |1665005791|
# |03e757be-c496-fb83-3268-854a8aeaf531|1809   |1664981809|true     |1101  |189808|false  |false    |false     |1665005791|
# |8e78ed0b-a2e5-3156-6106-32527d9f472f|14776  |1664982036|true     |15540 |189810|false  |true     |false     |1665005812|
# |e8dc2e6e-c327-991f-5364-c54829a4ea07|70     |1664982233|false    |10633 |189811|false  |true     |false     |1665005835|
# |08211e46-8400-c32e-9e21-cb5f7e92ec99|1753   |1664982233|true     |10633 |189812|false  |false    |false     |1665005835|
# |99c8662b-1dfd-ffaa-4f21-ccb72ef5b124|817    |1664982466|false    |48079 |189815|false  |true     |false     |1665005885|
# |f37046d3-6730-d941-61a0-c02f080b64ac|818    |1664982836|true     |48086 |189816|false  |true     |false     |1665005911|
# |600d280d-2a2a-c040-0d93-33cf111938bf|70     |1664983235|false    |1067  |189817|false  |true     |false     |1665005948|
# |39852957-11e2-1870-768f-3a8e25fe3e01|129    |1664983548|true     |3816  |189821|false  |true     |false     |1665005970|
# |b8edf5d3-0321-4733-59c1-901ef82f81f0|765    |1664983627|true     |74548 |189822|false  |false    |false     |1665005975|
# |8c53565b-424e-ae02-7d56-d4642d3f1312|70     |1664983627|false    |74548 |189823|false  |true     |false     |1665005975|
# +------------------------------------+-------+----------+---------+------+------+-------+---------+----------+----------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_involved_companies.printSchema()
# Out:
# root
#  |-- checksum: string (nullable = true)
#  |-- company: long (nullable = true)
#  |-- created_at: long (nullable = true)
#  |-- developer: boolean (nullable = true)
#  |-- game: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- porting: boolean (nullable = true)
#  |-- publisher: boolean (nullable = true)
#  |-- supporting: boolean (nullable = true)
#  |-- updated_at: long (nullable = true)

# %%
dfIGDB_involved_companies.count()
# Out:
# 170891

# %% [markdown]
# #### Exploração

# %%
# TO-DO

# %% [markdown]
# # Websites

# %% [markdown]
# ### Leitura da base

# %%
table_name = 'websites'

delta_table_path = bucket_path + table_name + '/delta/'

dfIGDB_websites = DeltaTable.forPath(spark, delta_table_path).toDF()

# %% [markdown]
# ### Conhecendo a Base

# %%
# Exibe o DataFrame resultante
dfIGDB_websites.show(truncate=False)
# Out:
# +--------+------------------------------------+----+---+-------+--------------------------------------------------------------+
# |category|checksum                            |game|id |trusted|url                                                           |
# +--------+------------------------------------+----+---+-------+--------------------------------------------------------------+
# |1       |1ece8bf8-1741-757e-673f-fcd071398143|115 |11 |false  |http://www.leagueoflegends.com                                |
# |1       |83fc76b2-befb-e0ec-e14d-7072bdfaaa65|120 |13 |false  |http://www.diablo3.com                                        |
# |1       |632b7585-1af8-3a6e-6a62-7ea3e246cb2c|126 |17 |false  |http://us.blizzard.com/en-us/games/d2/index.html              |
# |1       |ec217488-e5c3-69fb-c27f-5472ae523af1|141 |22 |false  |http://www.lucasarts.com/games/swbattlefront/                 |
# |1       |a53fe91f-142a-9d74-a135-8d0f2c56aefc|228 |32 |false  |http://www.worldofwarcraft.com/wrath                          |
# |1       |7c87b274-d806-b4a7-ba6f-d726e7fd479c|245 |34 |false  |http://www.commandandconquer.com/en/games/bygameid/ra2        |
# |1       |9df574b6-f5bb-6b56-ab57-41090365f58f|295 |37 |false  |http://www.commandandconquer.com/en/games/bygameid/ra         |
# |1       |40cf0bdb-6fc1-002c-a085-fde9dbad941b|301 |38 |false  |http://www.microsoft.com/games/flightsimulatorx/              |
# |1       |45418b46-a785-3e9d-b18c-31b85d7c1fb4|310 |39 |false  |http://www.civ3.com                                           |
# |1       |07024a82-07e8-2a3c-d0fe-758fd70ce29a|526 |64 |false  |http://www.needforspeed.com/therun                            |
# |1       |db0e26b4-3ba2-e689-109a-8e5681fae110|534 |71 |false  |http://www.zelda.com/skywardsword/                            |
# |1       |2081ea63-1964-cd22-e203-e7018bde69f4|547 |81 |false  |http://gearsofwar.xbox.com/                                   |
# |1       |13810768-2c98-929e-4407-79cb2c24bd59|554 |83 |false  |http://driver-thegame.ubi.com/driver-san-francisco/en-US/home/|
# |1       |b3ea5ea1-52fd-8ced-d83c-7d6b6442b4b0|557 |86 |false  |http://prisonbreak.deepsilver.com/                            |
# |1       |70155122-a6fb-2aaa-7783-3f60f5f3c56b|569 |98 |false  |http://www.wolfenstein.com                                    |
# |1       |cebe6d1d-6074-6633-6b1a-70ff09018e1a|575 |103|false  |http://godfather2.ea.com                                      |
# |1       |3d4f3fad-50ed-fe27-dad4-d0b7093018f6|595 |107|false  |http://www.freeallegiance.org                                 |
# |1       |b9709948-89a9-8f49-ecec-a6ec5ae3396b|597 |108|false  |http://www.americasarmy.com                                   |
# |1       |e44e6ba0-4f84-e659-688d-c73c29c699fa|647 |118|false  |http://www.commandandconquer.com/en/games/bygameid/cnc        |
# |1       |756e6fd4-e2ef-fa5b-70e7-d8e45748ad9b|723 |129|false  |http://www.galciv2.com/twilight                               |
# +--------+------------------------------------+----+---+-------+--------------------------------------------------------------+
# only showing top 20 rows

# %%
# Exibe o Schema do DataFrame
dfIGDB_websites.printSchema()
# Out:
# root
#  |-- category: long (nullable = true)
#  |-- checksum: string (nullable = true)
#  |-- game: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- trusted: boolean (nullable = true)
#  |-- url: string (nullable = true)

# %%
dfIGDB_websites.count()
# Out:
# 524679

# %% [markdown]
# #### Exploração

# %%
# TO-DO
